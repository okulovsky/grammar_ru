# %%
from tg.grammar_ru.ml.corpus import CorpusReader
from pathlib import Path
import os

base_path = Loc.corpus_path/'example.base.zip'))
reader = CorpusReader(Path(base_path))
db = reader.get_bundles().first()

# %%
from tg.grammar_ru.algorithms import AntecedentCandidatesAlgorithm

cls = AntecedentCandidatesAlgorithm()
candidates_df = cls.get_candidates(db)
candidates_df
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance
# 0                 10                  0                   0
# 1                 18                  0                   1
# 2                 18                 10                   0
# 3                 30                  0                   2
# 4                 30                 10                   1
# ..               ...                ...                 ...
# 428              921                907                   4
# 429              921                914                   3
# 430              921                917                   2
# 431              921                918                   1
# 432              921                919                   0
#
# [433 rows x 3 columns]

# %%
with_parent_df = cls.get_pronoun_parent(db, candidates_df)
with_parent_df
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  pronoun_parent_id
# 0                 10                  0                   0                  9
# 1                 18                  0                   1                 19
# 2                 18                 10                   0                 19
# 3                 30                  0                   2                 31
# 4                 30                 10                   1                 31
# ..               ...                ...                 ...                ...
# 428              921                907                   4                922
# 429              921                914                   3                922
# 430              921                917                   2                922
# 431              921                918                   1                922
# 432              921                919                   0                922
#
# [433 rows x 4 columns]

# %%
from tg.grammar_ru.common import Loc
Loc.corpus_path
# Out:
# WindowsPath('c:/users/alexandra/desktop/grammar_ru/data-cache/corpus')

# %%
from tg.grammar_ru.common import Loc
from navec import Navec
import pandas as pd

navec = Navec.load(Loc.data_cache_path/'glove.tar')
words = list(navec.vocab.words)
ndf = pd.DataFrame(dict(word=words)).reset_index().set_index('word').rename(columns={'index':'navec_index'})
ndf
# Out:
#        navec_index
# word
# a                0
# a-а              1
# aa               2
# aaa              3
# aan              4
# ...            ...
# ёь          499997
# ёю          499998
# ёё          499999
# <unk>       500000
# <pad>       500001
#
# [500002 rows x 1 columns]

# %%
def set_navec_index(df, df_column, index_name):
    df = df.merge(ndf, left_on=df_column, right_index=True, how='left')
    df.navec_index = df.navec_index.fillna(-1).astype(int)
    df = df.rename(columns={'navec_index': index_name})
    return df

product_df = with_parent_df.merge(db.pymorphy.normal_form.rename('pronoun_parent_norm'), left_on='pronoun_parent_id', right_index=True, how='left')
product_df = product_df.merge(db.pymorphy.normal_form.rename('candidate_word_norm'), left_on='candidate_word_id', right_index=True, how='left')
product_df = set_navec_index(product_df, 'pronoun_parent_norm', 'navec_index_norm_p')
product_df = set_navec_index(product_df, 'candidate_word_norm', 'navec_index_norm_c')
product_df
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                 10                  0                   0
# 1                 18                  0                   1
# 2                 18                 10                   0
# 3                 30                  0                   2
# 4                 30                 10                   1
# ..               ...                ...                 ...
# 428              921                907                   4
# 429              921                914                   3
# 430              921                917                   2
# 431              921                918                   1
# 432              921                919                   0
#
#      pronoun_parent_id pronoun_parent_norm candidate_word_norm  \
# 0                    9        преследовать               лилия
# 1                   19             гнаться               лилия
# 2                   19             гнаться                 она
# 3                   31          оставаться               лилия
# 4                   31          оставаться                 она
# ..                 ...                 ...                 ...
# 428                922             кубарем              жертва
# 429                922             кубарем              судьба
# 430                922             кубарем                 она
# 431                922             кубарем                роль
# 432                922             кубарем             героиня
#
#      navec_index_norm_p  navec_index_norm_c
# 0                333934              196876
# 1                 91055              196876
# 2                 91055              267314
# 3                273527              196876
# 4                273527              267314
# ..                  ...                 ...
# 428              187882              123688
# 429              187882              424227
# 430              187882              267314
# 431              187882              379575
# 432              187882               88162
#
# [433 rows x 8 columns]

# %%
pmph = db['pymorphy']
pronoun_form = pmph[pmph.index.isin(product_df['pronoun_word_id'])]['case']
product_df = product_df.merge(pronoun_form, left_on='pronoun_word_id', right_index=True, how='left')
product_df
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                 10                  0                   0
# 1                 18                  0                   1
# 2                 18                 10                   0
# 3                 30                  0                   2
# 4                 30                 10                   1
# ..               ...                ...                 ...
# 428              921                907                   4
# 429              921                914                   3
# 430              921                917                   2
# 431              921                918                   1
# 432              921                919                   0
#
#      pronoun_parent_id pronoun_parent_norm candidate_word_norm  \
# 0                    9        преследовать               лилия
# 1                   19             гнаться               лилия
# 2                   19             гнаться                 она
# 3                   31          оставаться               лилия
# 4                   31          оставаться                 она
# ..                 ...                 ...                 ...
# 428                922             кубарем              жертва
# 429                922             кубарем              судьба
# 430                922             кубарем                 она
# 431                922             кубарем                роль
# 432                922             кубарем             героиня
#
#      navec_index_norm_p  navec_index_norm_c  case
# 0                333934              196876  accs
# 1                 91055              196876  nomn
# 2                 91055              267314  nomn
# 3                273527              196876  datv
# 4                273527              267314  datv
# ..                  ...                 ...   ...
# 428              187882              123688  nomn
# 429              187882              424227  nomn
# 430              187882              267314  nomn
# 431              187882              379575  nomn
# 432              187882               88162  nomn
#
# [433 rows x 9 columns]

# %%
import pymorphy2

morph = pymorphy2.MorphAnalyzer()

def inflect(word, case):
    return morph.parse(word)[0].inflect({'sing', case}).word

product_df['candidate_inflected'] = product_df.apply(lambda x: inflect(x['candidate_word_norm'], x['case']), axis=1)
product_df = product_df.merge(db.src.word.rename('parent_original').str.lower(), left_on='pronoun_parent_id', right_index=True, how='left')
product_df = set_navec_index(product_df, 'parent_original', 'navec_index_orig_p')
product_df = set_navec_index(product_df, 'candidate_inflected', 'navec_index_infl_c')
product_df
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                 10                  0                   0
# 1                 18                  0                   1
# 2                 18                 10                   0
# 3                 30                  0                   2
# 4                 30                 10                   1
# ..               ...                ...                 ...
# 428              921                907                   4
# 429              921                914                   3
# 430              921                917                   2
# 431              921                918                   1
# 432              921                919                   0
#
#      pronoun_parent_id pronoun_parent_norm candidate_word_norm  \
# 0                    9        преследовать               лилия
# 1                   19             гнаться               лилия
# 2                   19             гнаться                 она
# 3                   31          оставаться               лилия
# 4                   31          оставаться                 она
# ..                 ...                 ...                 ...
# 428                922             кубарем              жертва
# 429                922             кубарем              судьба
# 430                922             кубарем                 она
# 431                922             кубарем                роль
# 432                922             кубарем             героиня
#
#      navec_index_norm_p  navec_index_norm_c  case candidate_inflected  \
# 0                333934              196876  accs               лилию
# 1                 91055              196876  nomn               лилия
# 2                 91055              267314  nomn                 она
# 3                273527              196876  datv               лилии
# 4                273527              267314  datv                  ей
# ..                  ...                 ...   ...                 ...
# 428              187882              123688  nomn              жертва
# 429              187882              424227  nomn              судьба
# 430              187882              267314  nomn                 она
# 431              187882              379575  nomn                роль
# 432              187882               88162  nomn             героиня
#
#     parent_original  navec_index_orig_p  navec_index_infl_c
# 0       преследовал              333907              196875
# 1           гналась               91045              196876
# 2           гналась               91045              267314
# 3         оставался              273526              196858
# 4         оставался              273526              121060
# ..              ...                 ...                 ...
# 428         кубарем              187882              123688
# 429         кубарем              187882              424227
# 430         кубарем              187882              267314
# 431         кубарем              187882              379575
# 432         кубарем              187882               88162
#
# [433 rows x 13 columns]

# %%
from slovnet.model.emb import NavecEmbedding
import torch

emb = NavecEmbedding(navec)
navec_indices = pd.concat([product_df.navec_index_norm_p, 
                           product_df.navec_index_norm_c,
                           product_df.navec_index_orig_p,
                           product_df.navec_index_infl_c]).unique()
input = torch.tensor([x for x in navec_indices if x!=-1])
output = emb(input.long())

gdf = pd.DataFrame(output.tolist())
gdf['navec_index'] = input.tolist()
gdf = gdf.set_index('navec_index')
gdf
# Out:
#                   0         1         2         3         4         5    \
# navec_index
# 333934      -0.112453 -0.306758  0.145285  0.443198  0.012505 -0.402717
# 91055        0.197562  0.080616  0.202884 -0.145310 -0.210084 -0.233264
# 273527       0.324312 -0.407607  0.037182  0.258735  0.011883 -0.093407
# 279254      -0.114882 -0.145657 -0.000606 -0.003198 -0.379298  0.049046
# 306432      -0.197706  0.084281  0.263474 -0.377358 -0.277203 -0.009678
# ...               ...       ...       ...       ...       ...       ...
# 356006       0.031675  0.324081 -0.347707  0.181894 -0.230779  0.424414
# 430919       0.021681  0.125735  0.251885  0.291416  0.111534  0.172244
# 286159      -0.020386 -0.430457 -0.312975  0.356807 -0.051699 -0.759013
# 195564       0.255090 -0.215287 -0.023806  0.459176 -0.728118 -0.492764
# 424232       0.255090 -0.215287 -0.023806  0.211407  0.962188  0.240126
#
#                   6         7         8         9    ...       290       291  \
# navec_index                                          ...
# 333934       0.076367 -0.220459 -0.387291 -0.110226  ... -0.016714 -0.334920
# 91055       -0.366435 -0.153203  0.040027 -0.130637  ... -0.285696 -0.110329
# 273527      -0.272309 -0.170452 -0.346471  0.389134  ...  0.608405 -0.013813
# 279254       0.040712 -0.146096 -0.085722  0.157008  ...  0.358176  0.438139
# 306432       0.225207 -0.082434  0.381535 -0.428462  ...  0.394494 -0.251483
# ...               ...       ...       ...       ...  ...       ...       ...
# 356006      -0.278897  0.194534  0.065564 -0.109867  ...  0.248024  0.149218
# 430919      -0.100932  0.270803 -0.265560 -0.142112  ... -0.580810  0.044219
# 286159       0.193865  0.405029 -0.045148 -0.282417  ... -0.425034  0.535372
# 195564      -0.021290  0.227721  0.504898 -0.398052  ... -0.180117  0.861375
# 424232      -0.129790 -0.565314 -0.050878 -0.169193  ... -0.002052 -0.110329
#
#                   292       293       294       295       296       297  \
# navec_index
# 333934      -0.647631 -0.436893 -0.075502  0.024846 -0.085273 -0.563138
# 91055       -0.043071 -0.677648  0.052566  0.173356  0.185777 -0.563138
# 273527      -0.186715 -0.477247  0.238254 -0.013511  0.056895 -0.169360
# 279254      -0.273677 -0.452074  0.196641 -0.409728  0.254586 -0.221693
# 306432      -0.158747 -0.058563  0.333999  0.179716 -0.109330 -0.062578
# ...               ...       ...       ...       ...       ...       ...
# 356006       0.158946  0.181778 -0.112056  0.058064  0.227423  0.733654
# 430919       0.162369  0.055797  0.235268  0.054568  0.218531  0.138013
# 286159      -0.295388 -0.221495 -0.469748 -0.408250 -0.391878 -0.080437
# 195564       0.068422 -0.299578  0.496512 -0.230196 -0.175848 -0.010044
# 424232      -0.043071 -0.677648 -0.220264  0.550848 -0.498602 -0.136865
#
#                   298       299
# navec_index
# 333934      -0.509545  0.423477
# 91055       -0.509545  0.423477
# 273527      -0.220133  0.849850
# 279254       0.168994 -0.096643
# 306432       0.218991  0.083121
# ...               ...       ...
# 356006       0.369591  0.111176
# 430919       0.243070  0.168594
# 286159      -0.233745 -0.014317
# 195564      -0.174519 -0.777815
# 424232       0.318385  0.750027
#
# [270 rows x 300 columns]

# %%
from tg.common.ml.miscellaneous.glove import GloveProcessor

def substract_embeddings_square(x_index, y_index):
    x = x_index.to_frame('idx').merge(gdf, left_on='idx', right_index=True, how='left').drop('idx', axis=1)
    y = y_index.to_frame('idx').merge(gdf, left_on='idx', right_index=True, how='left').drop('idx', axis=1)
    sub = x - y
    return (sub * sub).sum(axis=1)

product_df['norm_glove_square'] = substract_embeddings_square(product_df.navec_index_norm_p, product_df.navec_index_norm_c)
product_df['inflected_glove_square'] = substract_embeddings_square(product_df.navec_index_orig_p, product_df.navec_index_infl_c)
product_df[['pronoun_word_id', 'candidate_word_id', 'candidate_inflected', 'parent_original', 'norm_glove_square', 'inflected_glove_square']].head(40)
# Out:
#     pronoun_word_id  candidate_word_id candidate_inflected parent_original  \
# 0                10                  0               лилию     преследовал
# 1                18                  0               лилия         гналась
# 2                18                 10                 она         гналась
# 3                30                  0               лилии       оставался
# 4                30                 10                  ей       оставался
# 5                30                 18                  ей       оставался
# 6                48                  3          суетливого      оторваться
# 7                48                  5            путаного      оторваться
# 8                48                  6                 сна      оторваться
# 9                48                  8             кого-то      оторваться
# 10               48                 21             кого-то      оторваться
# 11               48                 33          последнего      оторваться
# 12               48                 34              прыжка      оторваться
# 13               48                 38              злодея      оторваться
# 14               53                  0               лилию         подвели
# 15               53                 10                  её         подвели
# 16               53                 18                  её         подвели
# 17               53                 30                  её         подвели
# 18               56                  0               лилия           упала
# 19               56                 10                 она           упала
# 20               56                 18                 она           упала
# 21               56                 30                 она           упала
# 22               56                 53                 она           упала
# 23               83                  0               лилия         увидела
# 24               83                 10                 она         увидела
# 25               83                 18                 она         увидела
# 26               83                 30                 она         увидела
# 27               83                 53                 она         увидела
# 28               83                 56                 она         увидела
# 29               83                 61             пустота         увидела
# 30               83                 65               лилия         увидела
# 31               83                 81                свой         увидела
# 32               83                 82             спальня         увидела
# 33              113                 82             спальня        напугала
# 34              113                 83                 она        напугала
# 35              113                 90              полный        напугала
# 36              113                 91                луна        напугала
# 37              113                 94               спина        напугала
# 38              113                100             кровать        напугала
# 39              113                104              глухая        напугала
#
#     norm_glove_square  inflected_glove_square
# 0           60.801662               55.235951
# 1           55.151395               56.689454
# 2           55.543009               57.023314
# 3           60.209949               72.378968
# 4           41.402170               47.968986
# 5           41.402170               47.968986
# 6           64.350067               60.892517
# 7           71.380800               69.869130
# 8           58.981638               55.766872
# 9           55.649469               51.369442
# 10          55.649469               51.369442
# 11          47.102775               48.763981
# 12          58.067740               54.307503
# 13          61.673312               54.671810
# 14          56.628594               55.526743
# 15          50.736403               54.553682
# 16          50.736403               54.553682
# 17          50.736403               54.553682
# 18          59.064480               45.886245
# 19          46.892827               36.640362
# 20          46.892827               36.640362
# 21          46.892827               36.640362
# 22          46.892827               36.640362
# 23          52.449812               49.084162
# 24          33.544624               27.779320
# 25          33.544624               27.779320
# 26          33.544624               27.779320
# 27          33.544624               27.779320
# 28          33.544624               27.779320
# 29          53.721233               61.751094
# 30          52.449812               49.084162
# 31          47.213692               54.088886
# 32          56.931019               57.989950
# 33          63.311967               56.835790
# 34          48.205850               44.449935
# 35          62.696160               65.392302
# 36          66.332991               57.549802
# 37          72.411903               64.497424
# 38          64.283665               64.408835
# 39          59.654075               54.444462

# %%
max_norm_square = product_df.groupby(['pronoun_word_id'])['norm_glove_square'].idxmax()
max_norm_square = max_norm_square.dropna().astype(int)

# %%
on_norm = product_df.loc[max_norm_square][['pronoun_word_id', 'candidate_word_id', 'candidate_distance', 'pronoun_parent_norm', 'candidate_word_norm', 'norm_glove_square']]
on_norm.head(10)
# Out:
#     pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                10                  0                   0
# 2                18                 10                   0
# 3                30                  0                   2
# 7                48                  5                   6
# 14               53                  0                   3
# 18               56                  0                   4
# 32               83                 82                   0
# 40              113                105                   2
# 48              122                105                   4
# 55              145                106                   7
#
#    pronoun_parent_norm candidate_word_norm  norm_glove_square
# 0         преследовать               лилия          60.801662
# 2              гнаться                 она          55.543009
# 3           оставаться               лилия          60.209949
# 7           оторваться             путаный          71.380800
# 14            подвести               лилия          56.628594
# 18              упасть               лилия          59.064480
# 32             увидеть             спальня          56.931019
# 40            напугать           кирпичный          78.826817
# 48         чувствовать           кирпичный          84.068237
# 55        подкараулить               стена          77.216060

# %% [markdown]
# Кто-то выше занялся ерундой.

# %%
from tg.common.ml.miscellaneous.glove import GloveProcessor

product_df['product_norm'] = GloveProcessor.apply_scores(product_df.navec_index_norm_p, product_df.navec_index_norm_c, gdf)
product_df['product_infl'] = GloveProcessor.apply_scores(product_df.navec_index_orig_p, product_df.navec_index_infl_c, gdf)
max_prod = product_df.groupby(['pronoun_word_id'])['product_norm'].idxmax()
max_prod = max_prod.dropna().astype(int)
product_df.loc[max_prod][['pronoun_word_id', 'candidate_word_id', 'candidate_distance', 'pronoun_parent_norm', 'candidate_word_norm', 'product_norm']]
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                 10                  0                   0
# 2                 18                 10                   0
# 4                 30                 10                   1
# 8                 48                  6                   5
# 15                53                 10                   2
# 19                56                 10                   3
# 24                83                 10                   8
# 42               113                110                   0
# 51               122                113                   1
# 56               145                110                   6
# 70               160                126                   2
# 75               174                113                   7
# 85               187                118                   7
# 94               224                145                   8
# 103              235                160                   9
# 116              281                224                   6
# 128              299                251                   4
# 142              335                312                   0
# 145              351                297                   7
# 155              365                275                   7
# 164              374                299                   8
# 181              407                400                   1
# 188              432                407                   4
# 194              435                400                   8
# 212              489                488                   0
# 213              493                435                   9
# 230              515                489                   2
# 237              560                489                   5
# 246              581                489                   6
# 258              583                521                   4
# 263              594                489                   9
# 279              599                548                   3
# 285              621                560                   7
# 301              628                614                   1
# 313              691                621                   9
# 323              693                628                   9
# 334              755                728                   8
# 343              771                728                   9
# 362              790                787                   0
# 372              799                795                   0
# 375              833                790                   7
# 385              858                803                   7
# 402              874                872                   0
# 405              905                858                   7
# 422              917                914                   0
# 425              921                894                   7
#
#     pronoun_parent_norm candidate_word_norm  product_norm
# 0          преследовать               лилия     -2.059554
# 2               гнаться                 она     -0.213960
# 4            оставаться                 она      8.539292
# 8            оторваться                 сон      5.280543
# 15             подвести                 она      1.963640
# 19               упасть                 она      7.820927
# 24              увидеть                 она     10.808409
# 42             напугать              ворона      4.477386
# 51          чувствовать                 она     10.140821
# 56         подкараулить              ворона      0.797098
# 70               успеть         расходиться      7.731837
# 75           показаться                 она      8.184802
# 85                 глаз              голова     12.817409
# 94           обратиться                 она      7.121079
# 103                тело                 она     10.779175
# 116               страх                 она      9.219752
# 128         разделаться              другой      1.888351
# 142               убить            поразить     13.767942
# 145               иметь             простой      7.726579
# 155              звезда               лилия      9.357345
# 164         учительница                 она     11.219723
# 181             суждено              думать      8.671623
# 188               выйти                 она     10.347264
# 194        прислушаться              думать      6.327329
# 212           соединять           соединять     31.093813
# 213              пройти                 она      8.053546
# 230              стоять                 она      7.111089
# 237                 нет                 она     12.918216
# 246          остановить                 она      8.255097
# 258          остановить                след      6.379183
# 263               стать                 она      9.346967
# 279                мочь                клир      4.659490
# 285               знать                 она     11.672926
# 301         поклониться     заклинательница      2.127608
# 313                 где                 она      9.653401
# 323              пройти                 она      8.053546
# 334       приготовиться             беготня      2.814961
# 343        промелькнуть             беготня      3.608380
# 362             страсть                сила     12.498523
# 372             ожидать               любой      6.328303
# 375                глаз                 она     12.185200
# 385              сердце                боль     17.090384
# 402             таиться             таиться     28.058566
# 405              жертва                 она      8.000144
# 422           уготовить              судьба      3.859842
# 425             кубарем            лестница      7.405688

# %%
max_prod = product_df.groupby(['pronoun_word_id'])['product_infl'].idxmax()
max_prod = max_prod.dropna().astype(int)
product_df.loc[max_prod][['pronoun_word_id', 'candidate_word_id', 'candidate_distance', 'pronoun_parent_norm', 'candidate_word_norm', 'product_norm']]
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                 10                  0                   0
# 2                 18                 10                   0
# 3                 30                  0                   2
# 7                 48                  5                   6
# 14                53                  0                   3
# 18                56                  0                   4
# 29                83                 61                   3
# 40               113                105                   2
# 48               122                105                   4
# 60               145                124                   2
# 70               160                126                   2
# 80               174                142                   2
# 88               187                126                   4
# 102              224                215                   0
# 108              235                208                   4
# 113              281                208                   9
# 123              299                215                   9
# 142              335                312                   0
# 143              351                288                   9
# 159              365                310                   3
# 165              374                310                   7
# 182              407                402                   0
# 183              432                385                   9
# 199              435                422                   3
# 208              489                467                   4
# 215              493                440                   7
# 223              515                440                   9
# 236              560                488                   6
# 243              581                485                   9
# 260              583                536                   2
# 265              594                504                   7
# 279              599                548                   3
# 291              621                613                   1
# 300              628                613                   2
# 303              666                584                   9
# 315              691                637                   7
# 324              693                637                   8
# 337              755                739                   5
# 346              771                739                   6
# 355              790                746                   7
# 363              799                746                   9
# 379              833                805                   3
# 386              858                805                   6
# 398              874                839                   4
# 411              905                894                   1
# 418              917                894                   4
# 431              921                918                   1
#
#     candidate_inflected parent_original  inflected_glove_square
# 0                 лилию     преследовал               55.235951
# 2                   она         гналась               57.023314
# 3                 лилии       оставался               72.378968
# 7              путаного      оторваться               69.869130
# 14                лилию         подвели               55.526743
# 18                лилия           упала               45.886245
# 29              пустота         увидела               61.751094
# 40            кирпичный        напугала               71.787097
# 48            кирпичный     чувствовала               83.369851
# 60              тревогу    подкараулили               79.414895
# 70         расходящийся          успела               79.261386
# 80                лилии      показалось               63.367330
# 88         расходящуюся          глазах               75.305527
# 102                 ран      обратилась               70.168785
# 108               лилию            телу               73.137607
# 113               лилию           страх               77.366983
# 123                 ран     разделалась               74.905462
# 142          поразившую           убить               66.221646
# 143            какая-то            имел               62.672790
# 159               порча         звездой               77.779815
# 165               порчу     учительница               75.103824
# 182               лилии         суждено               67.746116
# 183     заклинательницы           выйти               68.720767
# 199               битва    прислушалась               71.111423
# 208            слабость     соединяющую               82.449259
# 215           исходящий          прошла               64.992031
# 223           исходящем           стоял               82.919525
# 236        соединяющего             нет               65.024363
# 243            заметный       остановит               62.153668
# 260              творца       остановит               64.083339
# 265               лилии          станут               72.379940
# 279                клир           могла               70.029879
# 291          состоящему            знал               68.991156
# 300           состоящий     поклонилась               74.377891
# 303              самого             NaN                0.000000
# 315          отпирающий             где               70.805849
# 324          отпирающий          прошла               70.825134
# 337         праведность   приготовилась               76.769769
# 346         праведности    промелькнула               84.897844
# 355              пышный         страсть               74.640052
# 363              пышный         ожидала               60.195410
# 379         сдавленного          глазах               79.469979
# 386         сдавленного          сердце               83.040401
# 398               лилии       таившаяся               79.339605
# 411            лестница          жертва               64.681441
# 418            лестнице       уготовила               83.518292
# 431                роль         кубарем               84.660469

# %% [markdown]
# Ошибки:
#
# 0) Лилия очнулась от суетливого, путаного сна. Кто-то преследовал ее
#
# 8) путаного сна ... схватить _злодея_ — или, возможно, чтобы окончательно оторваться от него
#
# 42) Недалеко каркали вороны, которых она напугала
#
# 56) каркали вороны ... Лилия вспомнила. Ее подкараулили!
#
# 70) тревогу, расходившуюся волнами ... Лилия вспомнила. Ее подкараулили!
#
# 85) Голова кружилась ...  мир в ее глазах замерцал
#
# 128) Кто-нибудь другой ... С простым грабителем она бы в два счета разделалась
#
# 142) порча, поразившая споенец ... Ее хотел убить темный колдун
#
# ...
#
# В фильтрации надо было использовать slovnet, а не pymorphy

# %%
# фильтр на slovnet и меньше кандидатов на местоимение
from tg.grammar_ru.algorithms import AntecedentCandidatesAlgorithm

cls = AntecedentCandidatesAlgorithm(7)
candidates_df = cls.get_candidates(db)
with_parent_df = cls.get_pronoun_parent(db, candidates_df)
with_parent_df
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  pronoun_parent_id
# 0                 10                  0                   0                  9
# 1                 18                  0                   1                 19
# 2                 18                 10                   0                 19
# 3                 30                  0                   2                 31
# 4                 30                 10                   1                 31
# ..               ...                ...                 ...                ...
# 303              921                907                   4                922
# 304              921                914                   3                922
# 305              921                917                   2                922
# 306              921                918                   1                922
# 307              921                919                   0                922
#
# [308 rows x 4 columns]

# %%
from tg.grammar_ru.ml.features import NavecFeaturizer

prod_feat = NavecFeaturizer()

product_df = with_parent_df.merge(db.pymorphy.normal_form.rename('pronoun_parent_norm'), left_on='pronoun_parent_id', right_index=True, how='left')
product_df = product_df.merge(db.pymorphy.normal_form.rename('candidate_word_norm'), left_on='candidate_word_id', right_index=True, how='left')
product_df['norm_prod'] = prod_feat.get_glove_prod(product_df, 'pronoun_parent_norm', 'candidate_word_norm')
product_df
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                 10                  0                   0
# 1                 18                  0                   1
# 2                 18                 10                   0
# 3                 30                  0                   2
# 4                 30                 10                   1
# ..               ...                ...                 ...
# 303              921                907                   4
# 304              921                914                   3
# 305              921                917                   2
# 306              921                918                   1
# 307              921                919                   0
#
#      pronoun_parent_id pronoun_parent_norm candidate_word_norm  norm_prod
# 0                    9        преследовать               лилия  -2.059554
# 1                   19             гнаться               лилия  -1.109730
# 2                   19             гнаться                 она  -0.213960
# 3                   31          оставаться               лилия  -1.956175
# 4                   31          оставаться                 она   8.539292
# ..                 ...                 ...                 ...        ...
# 303                922             кубарем              жертва  -0.980053
# 304                922             кубарем              судьба  -1.951545
# 305                922             кубарем                 она  -0.423255
# 306                922             кубарем                роль  -1.972080
# 307                922             кубарем             героиня  -1.616519
#
# [308 rows x 7 columns]

# %%
def get_max(df, group_col, max_col):
    max_rows = df.groupby([group_col])[max_col].idxmax()
    max_rows = max_rows.dropna().astype(int)
    return df.loc[max_rows]

get_max(product_df, 'pronoun_word_id', 'norm_prod')
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                 10                  0                   0
# 2                 18                 10                   0
# 4                 30                 10                   1
# 8                 48                  6                   3
# 13                53                 10                   2
# 17                56                 10                   3
# 21                83                 30                   6
# 30               113                 95                   4
# 40               122                113                   1
# 48               145                142                   0
# 53               160                124                   2
# 56               174                113                   6
# 63               187                118                   6
# 70               224                145                   6
# 77               235                174                   6
# 85               281                224                   5
# 94               299                251                   3
# 101              335                293                   3
# 108              351                319                   3
# 112              365                275                   6
# 120              374                335                   5
# 127              407                374                   5
# 136              432                407                   3
# 141              435                407                   5
# 153              489                486                   0
# 160              493                489                   0
# 165              515                489                   2
# 169              560                489                   5
# 175              581                493                   6
# 183              583                521                   5
# 189              594                515                   6
# 199              599                578                   3
# 203              621                560                   6
# 215              628                614                   1
# 225              691                666                   5
# 231              693                666                   6
# 238              755                737                   6
# 246              771                743                   5
# 258              790                787                   0
# 265              799                795                   0
# 268              833                799                   4
# 273              858                803                   6
# 286              874                870                   0
# 289              905                874                   4
# 300              917                914                   0
# 302              921                905                   5
#
#      pronoun_parent_id pronoun_parent_norm candidate_word_norm  norm_prod
# 0                    9        преследовать               лилия  -2.059554
# 2                   19             гнаться                 она  -0.213960
# 4                   31          оставаться                 она   8.539292
# 8                   46          оторваться                 сон   5.280543
# 13                  52            подвести                 она   1.963640
# 17                  57              упасть                 она   7.820927
# 21                  84             увидеть                 она  10.808409
# 30                 114            напугать             девушка   5.793210
# 40                 123         чувствовать                 она  10.140821
# 48                 146        подкараулить               лилия  -0.378904
# 53                 163              успеть             тревога   5.222582
# 56                 175          показаться                 она   8.184802
# 63                 188                глаз              голова  12.817409
# 70                 226          обратиться                 она   7.121079
# 77                 236                тело                 она  10.779175
# 85                 282               страх                 она   9.219752
# 94                 304         разделаться              другой   1.888351
# 101                337               убить                 тот   9.902740
# 108                352               иметь               страх   6.890177
# 112                367              звезда               лилия   9.357345
# 120                375         учительница                 она  11.219723
# 127                408             суждено                 она   5.650711
# 136                430               выйти                 она  10.347264
# 141                436        прислушаться                 она   2.407869
# 153                488           соединять             ниточка   4.219445
# 160                494              пройти                 она   8.053546
# 165                516              стоять                 она   7.111089
# 169                561                 нет                 она  12.918216
# 175                582          остановить                 она   8.255097
# 183                582          остановить                след   6.379183
# 189                592               стать                 она   9.346967
# 199                615                мочь           замышлять   6.068759
# 203                603               знать                 она  11.672926
# 215                629         поклониться     заклинательница   2.127608
# 225                690                 где                 она   9.653401
# 231                694              пройти                 она   8.053546
# 238                756       приготовиться                воля   0.309872
# 246                772        промелькнуть            ловкость   0.888046
# 258                789             страсть                сила  12.498523
# 265                800             ожидать               любой   6.328303
# 268                834                глаз                 она  12.185200
# 273                859              сердце                боль  17.090384
# 286                872             таиться             тревога   4.722805
# 289                907              жертва                 она   8.000144
# 300                916           уготовить              судьба   3.859842
# 302                922             кубарем                 она  -0.423255

# %% [markdown]
# Замены имён собственных:

# %%
words = db.pymorphy[db.pymorphy['POS'] == 'NOUN']
head = words.groupby(['normal_form'])['normal_form'].count().sort_values(ascending=False).head(10)
top_words = head.to_frame().rename(columns={'normal_form': 'count'}).reset_index()
top_words
# Out:
#   normal_form  count
# 0       лилия     19
# 1        глаз      5
# 2     споенец      4
# 3      колдун      4
# 4     тревога      3
# 5      ворота      3
# 6  заклинание      3
# 7         дом      3
# 8        тело      3
# 9   грабитель      3

# %%
def is_noun_proper(noun):
    indices = list(db.pymorphy[db.pymorphy['normal_form'] == noun].index)
    words = db.src[db.src.index.isin(indices)]['word']
    return words.str[0].str.isupper().all()

top_words['is_proper'] = top_words['normal_form'].map(is_noun_proper)
top_words
# Out:
#   normal_form  count  is_proper
# 0       лилия     19       True
# 1        глаз      5      False
# 2     споенец      4      False
# 3      колдун      4      False
# 4     тревога      3      False
# 5      ворота      3      False
# 6  заклинание      3      False
# 7         дом      3      False
# 8        тело      3      False
# 9   грабитель      3      False

# %%
propers = list(top_words[top_words['is_proper']]['normal_form'])
replace = {'masc': 'мужчина', 'femn': 'женщина', 'neut': 'существо'}
replaced = list(map(lambda x: replace[db.pymorphy[db.pymorphy.normal_form == x].iloc[0]['gender']], propers))
propers_replace = dict(zip(propers, replaced))
propers_replace
# Out:
# {'лилия': 'женщина'}

# %%
replaces_series = db.pymorphy['normal_form'].apply(lambda x: propers_replace[x] if x in propers else x)
replaces_series
# Out:
# word_id
# 0         женщина
# 1        очнуться
# 2              от
# 3       суетливый
# 4               ,
#           ...
# 921           она
# 922       кубарем
# 923    покатиться
# 924          вниз
# 925             .
# Name: normal_form, Length: 926, dtype: object

# %%
from tg.grammar_ru.algorithms import AntecedentCandidatesAlgorithm
from tg.grammar_ru.ml.features import NavecFeaturizer

cls = AntecedentCandidatesAlgorithm(7)
prod_feat = NavecFeaturizer()

with_parent_df = cls.get_pronoun_parent(db)
product_df = with_parent_df.merge(replaces_series.rename('pronoun_parent_norm'), left_on='pronoun_parent_id', right_index=True, how='left')
product_df = product_df.merge(replaces_series.rename('candidate_word_norm'), left_on='candidate_word_id', right_index=True, how='left')
product_df['norm_prod'] = prod_feat.get_glove_prod(product_df, 'pronoun_parent_norm', 'candidate_word_norm')
get_max(product_df, 'pronoun_word_id', 'norm_prod')
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                 10                  0                   0
# 2                 18                 10                   0
# 4                 30                 10                   1
# 8                 48                  6                   3
# 13                53                 10                   2
# 17                56                 10                   3
# 21                83                 30                   6
# 30               113                 95                   4
# 40               122                113                   1
# 42               145                105                   6
# 53               160                124                   2
# 56               174                113                   6
# 63               187                118                   6
# 75               224                208                   1
# 77               235                174                   6
# 85               281                224                   5
# 94               299                251                   3
# 101              335                293                   3
# 108              351                319                   3
# 112              365                275                   6
# 121              374                355                   4
# 127              407                374                   5
# 136              432                407                   3
# 141              435                407                   5
# 153              489                486                   0
# 160              493                489                   0
# 161              515                470                   6
# 169              560                489                   5
# 175              581                493                   6
# 183              583                521                   5
# 189              594                515                   6
# 199              599                578                   3
# 203              621                560                   6
# 215              628                614                   1
# 225              691                666                   5
# 231              693                666                   6
# 238              755                737                   6
# 246              771                743                   5
# 258              790                787                   0
# 265              799                795                   0
# 268              833                799                   4
# 273              858                803                   6
# 286              874                870                   0
# 291              905                884                   2
# 300              917                914                   0
# 301              921                896                   6
#
#      pronoun_parent_id pronoun_parent_norm candidate_word_norm  norm_prod
# 0                    9        преследовать             женщина   2.660135
# 2                   19             гнаться                 она  -0.213960
# 4                   31          оставаться                 она   8.539292
# 8                   46          оторваться                 сон   5.280543
# 13                  52            подвести                 она   1.963640
# 17                  57              упасть                 она   7.820927
# 21                  84             увидеть                 она  10.808409
# 30                 114            напугать             девушка   5.793210
# 40                 123         чувствовать                 она  10.140821
# 42                 146        подкараулить           кирпичный  -0.722384
# 53                 163              успеть             тревога   5.222582
# 56                 175          показаться                 она   8.184802
# 63                 188                глаз              голова  12.817409
# 75                 226          обратиться             женщина   7.364973
# 77                 236                тело                 она  10.779175
# 85                 282               страх                 она   9.219752
# 94                 304         разделаться              другой   1.888351
# 101                337               убить                 тот   9.902740
# 108                352               иметь               страх   6.890177
# 112                367              звезда             женщина   7.217910
# 121                375         учительница             женщина  12.589792
# 127                408             суждено                 она   5.650711
# 136                430               выйти                 она  10.347264
# 141                436        прислушаться                 она   2.407869
# 153                488           соединять             ниточка   4.219445
# 160                494              пройти                 она   8.053546
# 161                516              стоять             женщина   8.331840
# 169                561                 нет                 она  12.918216
# 175                582          остановить                 она   8.255097
# 183                582          остановить                след   6.379183
# 189                592               стать                 она   9.346967
# 199                615                мочь           замышлять   6.068759
# 203                603               знать                 она  11.672926
# 215                629         поклониться     заклинательница   2.127608
# 225                690                 где                 она   9.653401
# 231                694              пройти                 она   8.053546
# 238                756       приготовиться                воля   0.309872
# 246                772        промелькнуть            ловкость   0.888046
# 258                789             страсть                сила  12.498523
# 265                800             ожидать               любой   6.328303
# 268                834                глаз                 она  12.185200
# 273                859              сердце                боль  17.090384
# 286                872             таиться             тревога   4.722805
# 291                907              жертва             женщина  12.141319
# 300                916           уготовить              судьба   3.859842
# 301                922             кубарем             женщина  -0.210612

# %%
cls = AntecedentCandidatesAlgorithm(5)
with_parent_df = cls.get_pronoun_parent(db)
product_df = with_parent_df.merge(replaces_series.rename('pronoun_parent_norm'), left_on='pronoun_parent_id', right_index=True, how='left')
product_df = product_df.merge(replaces_series.rename('candidate_word_norm'), left_on='candidate_word_id', right_index=True, how='left')
product_df['norm_prod'] = prod_feat.get_glove_prod(product_df, 'pronoun_parent_norm', 'candidate_word_norm')
get_max(product_df, 'pronoun_word_id', 'norm_prod')
# Out:
#      pronoun_word_id  candidate_word_id  candidate_distance  \
# 0                 10                  0                   0
# 2                 18                 10                   0
# 4                 30                 10                   1
# 7                 48                  6                   3
# 12                53                 10                   2
# 16                56                 10                   3
# 20                83                 56                   4
# 25               113                 95                   4
# 33               122                113                   1
# 38               145                124                   1
# 42               160                124                   2
# 45               174                122                   4
# 52               187                145                   2
# 58               224                208                   1
# 63               235                224                   1
# 65               281                231                   4
# 71               299                251                   3
# 76               335                293                   3
# 81               351                319                   3
# 89               365                355                   0
# 90               374                355                   4
# 99               407                402                   0
# 101              432                407                   3
# 108              435                432                   1
# 114              489                486                   0
# 119              493                489                   0
# 124              515                504                   0
# 125              560                493                   4
# 130              581                515                   4
# 135              583                535                   4
# 141              594                560                   3
# 146              599                578                   3
# 150              621                581                   4
# 158              628                614                   1
# 165              691                669                   4
# 174              693                691                   0
# 178              755                748                   1
# 181              771                746                   3
# 189              790                787                   0
# 194              799                795                   0
# 195              833                799                   4
# 200              858                829                   4
# 209              874                870                   0
# 212              905                884                   2
# 219              917                914                   0
# 222              921                917                   2
#
#      pronoun_parent_id pronoun_parent_norm candidate_word_norm  norm_prod
# 0                    9        преследовать             женщина   2.660135
# 2                   19             гнаться                 она  -0.213960
# 4                   31          оставаться                 она   8.539292
# 7                   46          оторваться                 сон   5.280543
# 12                  52            подвести                 она   1.963640
# 16                  57              упасть                 она   7.820927
# 20                  84             увидеть                 она  10.808409
# 25                 114            напугать             девушка   5.793210
# 33                 123         чувствовать                 она  10.140821
# 38                 146        подкараулить             тревога  -2.088039
# 42                 163              успеть             тревога   5.222582
# 45                 175          показаться                 она   8.184802
# 52                 188                глаз                 она  12.185200
# 58                 226          обратиться             женщина   7.364973
# 63                 236                тело                 она  10.779175
# 65                 282               страх               волна   8.068757
# 71                 304         разделаться              другой   1.888351
# 76                 337               убить                 тот   9.902740
# 81                 352               иметь               страх   6.890177
# 89                 367              звезда             женщина   7.217910
# 90                 375         учительница             женщина  12.589792
# 99                 408             суждено             женщина   5.551627
# 101                430               выйти                 она  10.347264
# 108                436        прислушаться                 она   2.407869
# 114                488           соединять             ниточка   4.219445
# 119                494              пройти                 она   8.053546
# 124                516              стоять             женщина   8.331840
# 125                561                 нет                 она  12.918216
# 130                582          остановить                 она   8.255097
# 135                582          остановить                 дом   4.527316
# 141                592               стать                 она   9.346967
# 146                615                мочь           замышлять   6.068759
# 150                603               знать                 она  11.672926
# 158                629         поклониться     заклинательница   2.127608
# 165                690                 где              тишина   8.043493
# 174                694              пройти                 она   8.053546
# 178                756       приготовиться        внушительный  -0.016905
# 181                772        промелькнуть              пышный  -0.514691
# 189                789             страсть                сила  12.498523
# 194                800             ожидать               любой   6.328303
# 195                834                глаз                 она  12.185200
# 200                859              сердце              тишина  10.291288
# 209                872             таиться             тревога   4.722805
# 212                907              жертва             женщина  12.141319
# 219                916           уготовить              судьба   3.859842
# 222                922             кубарем                 она  -0.423255
