# %% [markdown]
# # Seq2Vec Overview

# %%
from tg.grammar_ru.corpus import ParallelCorpus, CorpusReader
from tg.grammar_ru.common.separator.df_viewer import DfViewer
from tg.ca import Seq2VecMatcher
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Now we can use the Parallel Corpus class to have access to various subcorpuses.

# %%
parallel_corpus = ParallelCorpus(Path('./files/parallel_corpus.zip'))

# %%
book_reader: CorpusReader = parallel_corpus.ru_book
book_firts_chapter_id = book_reader.get_toc().filename[0]
book_chapter_df = book_reader.get_frames([book_firts_chapter_id]).first()

# %% [markdown]
# ### Now we know id of first chapter in the book.
#
# ### We can use parallel corpus to get the first chapter of the retell by mapping.

# %%
retell_chapter_df = parallel_corpus.get_mapped_data([book_firts_chapter_id],['ru_book_ru_retell']).first()['ru_book_ru_retell']

# %% [markdown]
# ### Finally, we can see which sentences from the book and retell match.

# %% [markdown]
# #### For this task we will use the Seq2VecConverter class, get_matches method.

# %%
matcher = Seq2VecMatcher()
matched_ids, matched_sentences = matcher.get_matches(book_chapter_df,retell_chapter_df,need_matching_df=True)

# %% [markdown]
# ### Now we can see the matched sentences.

# %%
df_to_display = pd.merge(book_chapter_df,matched_ids,left_on='sentence_id',right_on='sentence_id',how='left')
sentences_to_display = matcher.viewer.to_sentences_strings(df_to_display,'MatchedWith').to_frame()
sentences_to_display = pd.merge(df_to_display,sentences_to_display,left_on='MatchedWith',right_on='MatchedWith',how='left')

# %%
sentences_to_display
# Out:
#       word_id  sentence_id  word_index  paragraph_id  word_tail       word  \
# 0           0            0           0             0          1          В
# 1           1            0           1             0          1     начале
# 2           2            0           2             0          0       июля
# 3           3            0           3             0          1          ,
# 4           4            0           4             0          1          в
# ...       ...          ...         ...           ...        ...        ...
# 3238     3238          183           4            49          1      будто
# 3239     3239          183           5            49          1          в
# 3240     3240          183           6            49          1  некотором
# 3241     3241          183           7            49          0   волнении
# 3242     3242          183           8            49          0          .
#
#      word_type  word_length                               file_id  \
# 0           ru            1  5db7a05d-3e68-49d1-ac12-dcea52df2264
# 1           ru            6  5db7a05d-3e68-49d1-ac12-dcea52df2264
# 2           ru            4  5db7a05d-3e68-49d1-ac12-dcea52df2264
# 3        punct            1  5db7a05d-3e68-49d1-ac12-dcea52df2264
# 4           ru            1  5db7a05d-3e68-49d1-ac12-dcea52df2264
# ...        ...          ...                                   ...
# 3238        ru            5  5db7a05d-3e68-49d1-ac12-dcea52df2264
# 3239        ru            1  5db7a05d-3e68-49d1-ac12-dcea52df2264
# 3240        ru            9  5db7a05d-3e68-49d1-ac12-dcea52df2264
# 3241        ru            8  5db7a05d-3e68-49d1-ac12-dcea52df2264
# 3242     punct            1  5db7a05d-3e68-49d1-ac12-dcea52df2264
#
#                 corpus_id  MatchedWith  \
# 0     parallel_corpus.zip       631302
# 1     parallel_corpus.zip       631302
# 2     parallel_corpus.zip       631302
# 3     parallel_corpus.zip       631302
# 4     parallel_corpus.zip       631302
# ...                   ...          ...
# 3238  parallel_corpus.zip       631326
# 3239  parallel_corpus.zip       631326
# 3240  parallel_corpus.zip       631326
# 3241  parallel_corpus.zip       631326
# 3242  parallel_corpus.zip       631326
#
#                                              word_print
# 0     В начале июля, в чрезвычайно жаркое время, под...
# 1     В начале июля, в чрезвычайно жаркое время, под...
# 2     В начале июля, в чрезвычайно жаркое время, под...
# 3     В начале июля, в чрезвычайно жаркое время, под...
# 4     В начале июля, в чрезвычайно жаркое время, под...
# ...                                                 ...
# 3238  Но никто не разделял его счастия; молчаливый т...
# 3239  Но никто не разделял его счастия; молчаливый т...
# 3240  Но никто не разделял его счастия; молчаливый т...
# 3241  Но никто не разделял его счастия; молчаливый т...
# 3242  Но никто не разделял его счастия; молчаливый т...
#
# [3243 rows x 12 columns]

# %%
DfViewer().highlight('word_print','auto').tooltip('MatchedWith').to_html_display(sentences_to_display)
# Out:
# <p><span style="background-color:#8dd3c7;" title="631302">В</span> <span style="background-color:#8dd3c7;" title="631302">начале</span> <span style="background-color:#8dd3c7;" title="631302">июля</span><span style="background-color:#8dd3c7;" title="631302">,</span> <span style="background-color:#8dd3c7;" title="631302">в</span> <span style="background-color:#8dd3c7;" title="631302">чрезвычайно</span> <span style="background-color:#8dd3c7;" title="631302">жаркое</span> <span style="background-color:#8dd3c7;" title="631302">время</span><span style="background-color:#8dd3c7;" title="631302">,</span> <span style="background-color:#8dd3c7;" title="631302">под</span> <span style="background-color:#8dd3c7;" title="631302">вечер</span><span style="background-color:#8dd3c7;" title="631302">,</span> <span style="background-color:#8dd3c7;" title="631302">один</span> <span style="background-color:#8dd3c7;" title="631302">молодой</span> <span style="background-color:#8dd3c7;" title="631302">человек</span> <span style="background-color:#8dd3c7;" title="631302">вышел</span> <span style="background-color:#8dd3c7;" title="631302">из</span> <span style="background-color:#8dd3c7;" title="631302">своей</span> <span style="background-color:#8dd3c7;" title="631302">каморки</span><span style="background-color:#8dd3c7;" title="631302">,</span> <span style="background-color:#8dd3c7;" title="631302">которую</span> <span style="background-color:#8dd3c7;" title="631302">нанимал</span> <span style="background-color:#8dd3c7;" title="631302">от</span> <span style="background-color:#8dd3c7;" title="631302">жильцов</span> <span style="background-color:#8dd3c7;" title="631302">в</span> <span style="background-color:#8dd3c7;" title="631302">С—м</span> <span style="background-color:#8dd3c7;" title="631302">переулке</span><span style="background-color:#8dd3c7;" title="631302">,</span> <span style="background-color:#8dd3c7;" title="631302">на</span> <span style="background-color:#8dd3c7;" title="631302">улицу</span> <span style="background-color:#8dd3c7;" title="631302">и</span> <span style="background-color:#8dd3c7;" title="631302">медленно</span><span style="background-color:#8dd3c7;" title="631302">,</span> <span style="background-color:#8dd3c7;" title="631302">как</span> <span style="background-color:#8dd3c7;" title="631302">бы</span> <span style="background-color:#8dd3c7;" title="631302">в</span> <span style="background-color:#8dd3c7;" title="631302">нерешимости</span><span style="background-color:#8dd3c7;" title="631302">,</span> <span style="background-color:#8dd3c7;" title="631302">отправился</span> <span style="background-color:#8dd3c7;" title="631302">к</span> <span style="background-color:#8dd3c7;" title="631302">К—ну</span> <span style="background-color:#8dd3c7;" title="631302">мосту</span><span style="background-color:#8dd3c7;" title="631302">.</span><span style="background-color:#8dd3c7;" title="631302">1</span></p><p><span title="631303">Он <span title="631303">благополучно <span title="631303">избегнул <span title="631303">встречи <span title="631303">с <span title="631303">своею <span title="631303">хозяйкой <span title="631303">на <span title="631303">лестнице<span title="631303">. <span title="631303">Каморка <span title="631303">его <span title="631303">приходилась <span title="631303">под <span title="631303">самою <span title="631303">кровлей <span title="631303">высокого <span title="631303">пятиэтажного <span title="631303">дома <span title="631303">и <span title="631303">походила <span title="631303">более <span title="631303">на <span title="631303">шкаф<span title="631303">, <span title="631303">чем <span title="631303">на <span title="631303">квартиру<span title="631303">. <span title="631303">Квартирная <span title="631303">же <span title="631303">хозяйка <span title="631303">его<span title="631303">, <span title="631303">у <span title="631303">которой <span title="631303">он <span title="631303">нанимал <span title="631303">эту <span  ...
