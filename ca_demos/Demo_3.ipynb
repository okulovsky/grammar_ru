# %% [markdown]
# # Seq2Vec matching
# ## Overview
# This demo shows Seq2Vec matching technology between books and retells:
#  - extracting book frame and corresponding retell frame using parallel corpus relations
#  - sending frames data to Seq2Vec matcher, which matches book and retell sentences
#  - writing output data to separate .json file for further model learning

# %%
# !pip install sentence-transformers googletrans==3.1.0a0
# Out:
# Requirement already satisfied: sentence-transformers in f:\grammar_ru\.conda\lib\site-packages (3.0.0)
# Requirement already satisfied: googletrans==3.1.0a0 in f:\grammar_ru\.conda\lib\site-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in f:\grammar_ru\.conda\lib\site-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in f:\grammar_ru\.conda\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.7.22)
# Requirement already satisfied: hstspreload in f:\grammar_ru\.conda\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.1.1)
# Requirement already satisfied: sniffio in f:\grammar_ru\.conda\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Requirement already satisfied: chardet==3.* in f:\grammar_ru\.conda\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in f:\grammar_ru\.conda\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in f:\grammar_ru\.conda\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in f:\grammar_ru\.conda\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in f:\grammar_ru\.conda\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in f:\grammar_ru\.conda\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in f:\grammar_ru\.conda\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in f:\grammar_ru\.conda\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in f:\grammar_ru\.conda\lib\site-packages (from sentence-transformers) (4.40.1)
# Requirement already satisfied: tqdm in f:\grammar_ru\.conda\lib\site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.11.0 in f:\grammar_ru\.conda\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: numpy in f:\grammar_ru\.conda\lib\site-packages (from sentence-transformers) (1.24.1)
# Requirement already satisfied: scikit-learn in f:\grammar_ru\.conda\lib\site-packages (from sentence-transformers) (1.2.0)
# Requirement already satisfied: scipy in f:\grammar_ru\.conda\lib\site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in f:\grammar_ru\.conda\lib\site-packages (from sentence-transformers) (0.22.2)
# Requirement already satisfied: Pillow in f:\grammar_ru\.conda\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in f:\grammar_ru\.conda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.8.2)
# Requirement already satisfied: fsspec>=2023.5.0 in f:\grammar_ru\.conda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in f:\grammar_ru\.conda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in f:\grammar_ru\.conda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0)
# Requirement already satisfied: requests in f:\grammar_ru\.conda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in f:\grammar_ru\.conda\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.4.0)
# Requirement already satisfied: colorama in f:\grammar_ru\.conda\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in f:\grammar_ru\.conda\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in f:\grammar_ru\.conda\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in f:\grammar_ru\.conda\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in f:\grammar_ru\.conda\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in f:\grammar_ru\.conda\lib\site-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in f:\grammar_ru\.conda\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in f:\grammar_ru\.conda\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.14)

# %%
from grammar_ru.corpus import ParallelCorpus, CorpusReader
from grammar_ru.common.separator.df_viewer import DfViewer
from grammar_ru.common.separator import Separator
from ca import Seq2VecMatcher
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Data extracting
#
# Extracting: books data, retells, data and their relations data from prepared previously parallel corpus.

# %%
parallel_corpus = ParallelCorpus(Path('./files/parallel_corpus.zip'))

# %%
book_reader: CorpusReader = parallel_corpus.ru_book
book_firts_chapter_id = 'ru_book_0'
book_chapter_df = book_reader.get_frames(['ru_book_0']).first()

# %%
book_chapter_df
# Out:
#       word_id  sentence_id  word_index  paragraph_id  word_tail       word  \
# 0           0            0           0             0          1          В
# 1           1            0           1             0          1     начале
# 2           2            0           2             0          0       июля
# 3           3            0           3             0          1          ,
# 4           4            0           4             0          1          в
# ...       ...          ...         ...           ...        ...        ...
# 3238     3238          183           4            49          1      будто
# 3239     3239          183           5            49          1          в
# 3240     3240          183           6            49          1  некотором
# 3241     3241          183           7            49          0   волнении
# 3242     3242          183           8            49          0          .
#
#      word_type  word_length    file_id            corpus_id
# 0           ru            1  ru_book_0  parallel_corpus.zip
# 1           ru            6  ru_book_0  parallel_corpus.zip
# 2           ru            4  ru_book_0  parallel_corpus.zip
# 3        punct            1  ru_book_0  parallel_corpus.zip
# 4           ru            1  ru_book_0  parallel_corpus.zip
# ...        ...          ...        ...                  ...
# 3238        ru            5  ru_book_0  parallel_corpus.zip
# 3239        ru            1  ru_book_0  parallel_corpus.zip
# 3240        ru            9  ru_book_0  parallel_corpus.zip
# 3241        ru            8  ru_book_0  parallel_corpus.zip
# 3242     punct            1  ru_book_0  parallel_corpus.zip
#
# [3243 rows x 10 columns]

# %% [markdown]
# Now we can use parallel corpus to get the first chapter of the retell by mapping.

# %%
retell_reader: CorpusReader = parallel_corpus.ru_retell
retell_reader.get_toc()
retell_firts_chapter_id = 'ru_retell_0'
retell_chapter_df = retell_reader.get_frames(['ru_retell_0']).first()
retell_chapter_df
# Out:
#         word_id  sentence_id  word_index  paragraph_id  word_tail        word  \
# 631302   631302       631302           0        631302          1           В
# 631303   631303       631302           1        631302          1  Петербурге
# 631304   631304       631302           2        631302          1      жаркое
# 631305   631305       631302           3        631302          1           и
# 631306   631306       631302           4        631302          1      душное
# ...         ...          ...         ...           ...        ...         ...
# 631693   631693       631326          16        631305          1     похожий
# 631694   631694       631326          17        631305          1          на
# 631695   631695       631326          18        631305          1  отставного
# 631696   631696       631326          19        631305          0   чиновника
# 631697   631697       631326          20        631305          0           .
#
#        word_type  word_length      file_id            corpus_id  \
# 631302        ru            1  ru_retell_0  parallel_corpus.zip
# 631303        ru           10  ru_retell_0  parallel_corpus.zip
# 631304        ru            6  ru_retell_0  parallel_corpus.zip
# 631305        ru            1  ru_retell_0  parallel_corpus.zip
# 631306        ru            6  ru_retell_0  parallel_corpus.zip
# ...          ...          ...          ...                  ...
# 631693        ru            7  ru_retell_0  parallel_corpus.zip
# 631694        ru            2  ru_retell_0  parallel_corpus.zip
# 631695        ru           10  ru_retell_0  parallel_corpus.zip
# 631696        ru            9  ru_retell_0  parallel_corpus.zip
# 631697     punct            1  ru_retell_0  parallel_corpus.zip
#
#         original_word_id  original_sentence_id  original_paragraph_id  updated
# 631302                 0                     0                      0    False
# 631303                 1                     0                      0    False
# 631304                 2                     0                      0    False
# 631305                 3                     0                      0    False
# 631306                 4                     0                      0    False
# ...                  ...                   ...                    ...      ...
# 631693               391                    24                      6    False
# 631694               392                    24                      6    False
# 631695               393                    24                      6    False
# 631696               394                    24                      6    False
# 631697               395                    24                      6    False
#
# [396 rows x 14 columns]

# %%
retell_chapter_df = parallel_corpus.get_mapped_data([book_firts_chapter_id],['ru_book_ru_retell']).first()['ru_book_ru_retell']

# %%
retell_chapter_df
# Out:
#         word_id  sentence_id  word_index  paragraph_id  word_tail        word  \
# 631302   631302       631302           0        631302          1           В
# 631303   631303       631302           1        631302          1  Петербурге
# 631304   631304       631302           2        631302          1      жаркое
# 631305   631305       631302           3        631302          1           и
# 631306   631306       631302           4        631302          1      душное
# ...         ...          ...         ...           ...        ...         ...
# 631693   631693       631326          16        631305          1     похожий
# 631694   631694       631326          17        631305          1          на
# 631695   631695       631326          18        631305          1  отставного
# 631696   631696       631326          19        631305          0   чиновника
# 631697   631697       631326          20        631305          0           .
#
#        word_type  word_length      file_id            corpus_id  \
# 631302        ru            1  ru_retell_0  parallel_corpus.zip
# 631303        ru           10  ru_retell_0  parallel_corpus.zip
# 631304        ru            6  ru_retell_0  parallel_corpus.zip
# 631305        ru            1  ru_retell_0  parallel_corpus.zip
# 631306        ru            6  ru_retell_0  parallel_corpus.zip
# ...          ...          ...          ...                  ...
# 631693        ru            7  ru_retell_0  parallel_corpus.zip
# 631694        ru            2  ru_retell_0  parallel_corpus.zip
# 631695        ru           10  ru_retell_0  parallel_corpus.zip
# 631696        ru            9  ru_retell_0  parallel_corpus.zip
# 631697     punct            1  ru_retell_0  parallel_corpus.zip
#
#         original_word_id  original_sentence_id  original_paragraph_id  updated
# 631302                 0                     0                      0    False
# 631303                 1                     0                      0    False
# 631304                 2                     0                      0    False
# 631305                 3                     0                      0    False
# 631306                 4                     0                      0    False
# ...                  ...                   ...                    ...      ...
# 631693               391                    24                      6    False
# 631694               392                    24                      6    False
# 631695               393                    24                      6    False
# 631696               394                    24                      6    False
# 631697               395                    24                      6    False
#
# [396 rows x 14 columns]

# %% [markdown]
# ### Finally, we can see which sentences from the book and retell match.

# %% [markdown]
# For this task we will use the Seq2VecConverter class, get_matches method.

# %%
matcher = Seq2VecMatcher()
matched_ids, matched_sentences = matcher.get_matches(book_chapter_df,retell_chapter_df,need_matching_df=True)

# %%
matched_sentences
# Out:
# В начале июля, в чрезвычайно жаркое время, под вечер, один молодой человек вышел из своей каморки, которую нанимал от жильцов в С—м переулке, на улицу и медленно, как бы в нерешимости, отправился к К—ну мосту.1                                                                                   В Петербурге жаркое и душное лето.
# Он благополучно избегнул встречи с своею хозяйкой на лестнице.                                                                                                                                                                                                                         Один молодой человек выходит из своей каморки,...
# Каморка его приходилась под самою кровлей высокого пятиэтажного дома и походила более на шкаф, чем на квартиру.                                                                                                                                                                        Один молодой человек выходит из своей каморки,...
# Квартирная же хозяйка его, у которой он нанимал эту каморку с обедом и прислугой, помещалась одною лестницей ниже, в отдельной квартире, и каждый раз, при выходе на улицу, ему непременно надо было проходить мимо хозяйкиной кухни, почти всегда настежь отворенной на лестницу.     Один молодой человек выходит из своей каморки,...
# И каждый раз молодой человек, проходя мимо, чувствовал какое-то болезненное и трусливое ощущение, которого стыдился и от которого морщился.                                                                                                                                            Один молодой человек выходит из своей каморки,...
#                                                                                                                                                                                                                                                                                                              ...
# Свою прежнюю нашел…4                                                                                                                                                                                                                                                                                      Он набрел на трактир и вошел.
# Но никто не разделял его счастия; молчаливый товарищ его смотрел на все эти взрывы даже враждебно и с недоверчивостью.                                                                                                                                                                 Там было мало народу, но Раскольникову бросилс...
# Был тут и еще один человек, с виду похожий как бы на отставного чиновника.                                                                                                                                                                                                             Там было мало народу, но Раскольникову бросилс...
# Он сидел особо, перед своею посудинкой, изредка отпивая и посматривая кругом.                                                                                                                                                                                                          Там было мало народу, но Раскольникову бросилс...
# Он был тоже как будто в некотором волнении.                                                                                                                                                                                                                                            Там было мало народу, но Раскольникову бросилс...
# Name: matched_sentence, Length: 184, dtype: object

# %%
matched_sentences.array
# Out:
# <PandasArray>
# [                                                                                                  'В Петербурге жаркое и душное лето. ',
#              'Один молодой человек выходит из своей каморки, пытаясь избежать встречи с хозяйкой — он давно уже не платит за квартиру. ',
#              'Один молодой человек выходит из своей каморки, пытаясь избежать встречи с хозяйкой — он давно уже не платит за квартиру. ',
#              'Один молодой человек выходит из своей каморки, пытаясь избежать встречи с хозяйкой — он давно уже не платит за квартиру. ',
#              'Один молодой человек выходит из своей каморки, пытаясь избежать встречи с хозяйкой — он давно уже не платит за квартиру. ',
#              'Один молодой человек выходит из своей каморки, пытаясь избежать встречи с хозяйкой — он давно уже не платит за квартиру. ',
#                                                     'Его гордость страдает от этого, а потому настроение героя нельзя назвать хорошим. ',
#  'В последнее время он вообще стал напоминать ипохондрика: тяготился обществом людей, избегал их и говорил преимущественно сам с собой.',
#  'В последнее время он вообще стал напоминать ипохондрика: тяготился обществом людей, избегал их и говорил преимущественно сам с собой.',
#                                            'Выйдя на улицу, он обдумывает какое-то таинственное дело, на которое он якобы не способен. ',
#  ...
#                                                                                                         'Он набрел на трактир и вошел. ',
#                                                                                                         'Он набрел на трактир и вошел. ',
#                                                                                                         'Он набрел на трактир и вошел. ',
#                                                                                                         'Он набрел на трактир и вошел. ',
#                                                                                                         'Он набрел на трактир и вошел. ',
#                                                                                                         'Он набрел на трактир и вошел. ',
#      'Там было мало народу, но Раскольникову бросился в глаза один тревожный и сосредоточенный пьяный, похожий на отставного чиновника.',
#      'Там было мало народу, но Раскольникову бросился в глаза один тревожный и сосредоточенный пьяный, похожий на отставного чиновника.',
#      'Там было мало народу, но Раскольникову бросился в глаза один тревожный и сосредоточенный пьяный, похожий на отставного чиновника.',
#      'Там было мало народу, но Раскольникову бросился в глаза один тревожный и сосредоточенный пьяный, похожий на отставного чиновника.']
# Length: 184, dtype: object

# %%
matched_ids['MatchedWithSentence'] = matched_sentences.array

# %%
matched_ids
# Out:
#      sentence_id  MatchedWith  \
# 0              0       631302
# 1              1       631303
# 2              2       631303
# 3              3       631303
# 4              4       631303
# ..           ...          ...
# 179          179       631325
# 180          180       631326
# 181          181       631326
# 182          182       631326
# 183          183       631326
#
#                                    MatchedWithSentence
# 0                  В Петербурге жаркое и душное лето.
# 1    Один молодой человек выходит из своей каморки,...
# 2    Один молодой человек выходит из своей каморки,...
# 3    Один молодой человек выходит из своей каморки,...
# 4    Один молодой человек выходит из своей каморки,...
# ..                                                 ...
# 179                     Он набрел на трактир и вошел.
# 180  Там было мало народу, но Раскольникову бросилс...
# 181  Там было мало народу, но Раскольникову бросилс...
# 182  Там было мало народу, но Раскольникову бросилс...
# 183  Там было мало народу, но Раскольникову бросилс...
#
# [184 rows x 3 columns]

# %% [markdown]
# ### Now we can see the matched sentences.

# %%
df_to_display = pd.merge(book_chapter_df,matched_ids,left_on='sentence_id',right_on='sentence_id',how='left')
sentences_to_display = matcher.viewer.to_sentences_strings(df_to_display,'MatchedWith').to_frame()
sentences_to_display = pd.merge(df_to_display,sentences_to_display,left_on='MatchedWith',right_on='MatchedWith',how='left')

# %%
sentences_to_display
# Out:
#       word_id  sentence_id  word_index  paragraph_id  word_tail       word  \
# 0           0            0           0             0          1          В
# 1           1            0           1             0          1     начале
# 2           2            0           2             0          0       июля
# 3           3            0           3             0          1          ,
# 4           4            0           4             0          1          в
# ...       ...          ...         ...           ...        ...        ...
# 3238     3238          183           4            49          1      будто
# 3239     3239          183           5            49          1          в
# 3240     3240          183           6            49          1  некотором
# 3241     3241          183           7            49          0   волнении
# 3242     3242          183           8            49          0          .
#
#      word_type  word_length    file_id            corpus_id  MatchedWith  \
# 0           ru            1  ru_book_0  parallel_corpus.zip       631302
# 1           ru            6  ru_book_0  parallel_corpus.zip       631302
# 2           ru            4  ru_book_0  parallel_corpus.zip       631302
# 3        punct            1  ru_book_0  parallel_corpus.zip       631302
# 4           ru            1  ru_book_0  parallel_corpus.zip       631302
# ...        ...          ...        ...                  ...          ...
# 3238        ru            5  ru_book_0  parallel_corpus.zip       631326
# 3239        ru            1  ru_book_0  parallel_corpus.zip       631326
# 3240        ru            9  ru_book_0  parallel_corpus.zip       631326
# 3241        ru            8  ru_book_0  parallel_corpus.zip       631326
# 3242     punct            1  ru_book_0  parallel_corpus.zip       631326
#
#                                     MatchedWithSentence  \
# 0                   В Петербурге жаркое и душное лето.
# 1                   В Петербурге жаркое и душное лето.
# 2                   В Петербурге жаркое и душное лето.
# 3                   В Петербурге жаркое и душное лето.
# 4                   В Петербурге жаркое и душное лето.
# ...                                                 ...
# 3238  Там было мало народу, но Раскольникову бросилс...
# 3239  Там было мало народу, но Раскольникову бросилс...
# 3240  Там было мало народу, но Раскольникову бросилс...
# 3241  Там было мало народу, но Раскольникову бросилс...
# 3242  Там было мало народу, но Раскольникову бросилс...
#
#                                              word_print
# 0     В начале июля, в чрезвычайно жаркое время, под...
# 1     В начале июля, в чрезвычайно жаркое время, под...
# 2     В начале июля, в чрезвычайно жаркое время, под...
# 3     В начале июля, в чрезвычайно жаркое время, под...
# 4     В начале июля, в чрезвычайно жаркое время, под...
# ...                                                 ...
# 3238  Но никто не разделял его счастия; молчаливый т...
# 3239  Но никто не разделял его счастия; молчаливый т...
# 3240  Но никто не разделял его счастия; молчаливый т...
# 3241  Но никто не разделял его счастия; молчаливый т...
# 3242  Но никто не разделял его счастия; молчаливый т...
#
# [3243 rows x 13 columns]

# %%
## доделать вместо word_print возникало предложение пересказ
DfViewer().highlight('word_print','auto').tooltip('MatchedWithSentence').to_html_display(sentences_to_display)
# Out:
# <p><span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">В</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">начале</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">июля</span><span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">,</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">в</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">чрезвычайно</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">жаркое</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">время</span><span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">,</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">под</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">вечер</span><span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">,</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">один</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">молодой</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">человек</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">вышел</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">из</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">своей</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">каморки</span><span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">,</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">которую</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">нанимал</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">от</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">жильцов</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">в</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">С—м</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">переулке</span><span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">,</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">на</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">улицу</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">и</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">медленно</span><span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">,</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">как</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">бы</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">в</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">нерешимости</span><span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">,</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">отправился</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">к</span> <span style="background-color:#8dd3c7;" title="В Петербурге жаркое и душное лето. ">К—ну</span> <span style="background-color:#8dd3c7;" title="В Петербурге жар ...

# %%
Separator.Viewer().to_sentences_strings(sentences_to_display)
# Out:
# sentence_id
# 0      В начале июля, в чрезвычайно жаркое время, под...
# 1      Он благополучно избегнул встречи с своею хозяй...
# 2      Каморка его приходилась под самою кровлей высо...
# 3      Квартирная же хозяйка его, у которой он нанима...
# 4      И каждый раз молодой человек, проходя мимо, чу...
#                              ...
# 179                                 Свою прежнюю нашел…4
# 180    Но никто не разделял его счастия; молчаливый т...
# 181    Был тут и еще один человек, с виду похожий как...
# 182    Он сидел особо, перед своею посудинкой, изредк...
# 183          Он был тоже как будто в некотором волнении.
# Name: word_print, Length: 184, dtype: object

# %%
sent_dataset = sentences_to_display[['MatchedWithSentence', 'word_print']]
sent_dataset = sent_dataset.drop_duplicates(subset=['word_print'], keep='first', )
sent_dataset = sent_dataset.reset_index(drop=True)
sent_dataset
# Out:
#                                   MatchedWithSentence  \
# 0                 В Петербурге жаркое и душное лето.
# 1   Один молодой человек выходит из своей каморки,...
# 2   Его гордость страдает от этого, а потому настр...
# 3   В последнее время он вообще стал напоминать ип...
# 4   Выйдя на улицу, он обдумывает какое-то таинств...
# 5   Его тревожит, что он не соответствует тому дел...
# 6   Герой нарочно растравляет себя мыслями о том, ...
# 7   Колорит улиц вторит его мрачным думам: везде п...
# 8   На улице его грубо окликнули «немецким шляпник...
# 9   Он рассуждает про себя, что шляпа погубит все ...
# 10                            Она слишком приметная.
# 11  Но весь вид молодого человека был таковым: он ...
# 12  Герой дошел до дома и зашел в подъезд, попутно...
# 13  Он позвонил, и его на пороге встретила старуха...
# 14  Она подозрительно смотрит на него и неохотно з...
# 15  Герой представился Родионом Раскольниковым и п...
# 16              Старуха оценила их на полтора рубля.
# 17              Все попытки торга были безуспешными.
# 18  Пока она возится с комодом и достает деньги, Р...
# 19  Судя по мыслям Родиона, можно заключить, что о...
# 20  Выйдя от старухи, герой ощущает отвращение к с...
# 21                      Он точно не способен на ЭТО!
# 22  Все мысли о деле кажутся ему мерзкими, недосто...
# 23                     Он набрел на трактир и вошел.
# 24  Там было мало народу, но Раскольникову бросилс...
#
#                                            word_print
# 0   В начале июля, в чрезвычайно жаркое время, под...
# 1   Он благополучно избегнул встречи с своею хозяй...
# 2   Не то чтоб он был так труслив и забит, совсем ...
# 3   Он до того углубился в себя и уединился от все...
# 4   Насущными делами своими он совсем перестал и н...
# 5   Никакой хозяйки, в сущности, он не боялся, что...
# 6   Но останавливаться на лестнице, слушать всякий...
# 7   «На какое дело хочу покуситься и в то же время...
# 8          Любопытно, чего люди больше всего боятся?
# 9   Нового шага, нового собственного слова они все...
# 10  А впрочем, я слишком много болтаю. Оттого и ни...
# 11  На улице жара стояла страшная, к тому же духот...
# 12  С замиранием сердца и нервною дрожью подошел о...
# 13  Старуха стояла перед ним молча и вопросительно...
# 14  «Может, впрочем, она и всегда такая, да я в то...
# 15  — Пройдите, батюшка.Небольшая комната, в котор...
# 16  Но в комнате не было ничего особенного. Мебель...
# 17    Молодой человек спорить не стал и взял деньги.
# 18  Он смотрел на старуху и не спешил уходить, точ...
# 19                                     Уж вы сейчас…
# 20  Прощайте, Алена Ивановна!Раскольников вышел в ...
# 21  «О боже! как это всё отвратительно! И неужели,...
# 22  Чувство бесконечного отвращения, начинавшее да...
# 23  В распивочной на ту пору оставалось мало народ...
# 24  Но никто не разделял его счастия; молчаливый т...

# %%
sent_dataset_json = sent_dataset.to_json(orient="records", force_ascii=False)

# %%
sent_dataset_json
print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 sent_dataset_json
# ----> 2 print()
#
# Cell In[34], line 2
#       1 sent_dataset_json
# ----> 2 print()
#
# File _pydevd_bundle/pydevd_cython.pyx:1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1152, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1135, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:312, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File f:\grammar_ru\.conda\lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File f:\grammar_ru\.conda\lib\site-packages\debugpy\_vendored\pydevd\pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %% [markdown]
# #### Write data from matcher to .json file.

# %%
file_path = "data/chapter_0.json"

import os
os.makedirs(os.path.dirname(file_path), exist_ok=True)

with open(file_path, 'w', encoding='utf-8') as file:
    file.write(sent_dataset_json)
