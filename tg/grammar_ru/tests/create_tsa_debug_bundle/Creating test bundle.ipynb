# %% [markdown]
# ## Introduction
#
# If there are few (typically 2) ways of using the word in a sentence and only one of them is correct, we call it an _alternative problem_, and the word we call _problematic word_. The typical example in English language is whether to write the ending -s to the verb: "I see", but "she sees". In Russian, these alternative problems are much more present and deserve their own codebase.
#
# The approach is to take the correct sentences, replace the problematic words with their counterparts, thus building negative samples. Also, when doing it, we want to balance the sentences by corpus and by length, as these factors often affect the performance. Finally, when we merge the data from different corpora, we want to update `sentence_id`, `word_id` and `paragraph_id`, as those must be unique in the dataset.

# %% [markdown]
# ## TSA
#
# TSA is an alternative problem where verbs have similar but different endings in invinitive (ться) and finite form (тся). No all the verbs are like this (e.g. нравится/нравиться, but хочется/хотеться), so first we need to filter the verbs that are _problematic_.
#
# ### Creating dictionary

# %% [markdown]
# First, let's define the list of corpora we will use in our bundle. Assume we have three corpora: news, publicistics and books.

# %%
from tg.grammar_ru import Loc

corpora = [
#    Loc.corpus_path/'books.base.zip',
#    Loc.corpus_path/'pub.base.zip',
    Loc.corpus_path/'lenta.base.zip',
]

# %% [markdown]
# Not every sentence in the corpora contains problematic word, so first we need to detect the sentences that are required in the bundle. For this particular task we will use a dictionary approach: we will scan the corpora and find verbs that are presented there in both -тся and -ться forms.

# %%
from yo_fluq_ds import *

good_words = set(FileIO.read_json('tsa-dict.json'))
list(good_words)[:5]
# Out:
# ['оправиться', 'изводиться', 'сговориться', 'отмахнуться', 'нереститься']

# %% [markdown]
# ## Balancing dataset
#
#
# We want an equal representation of the sentences of different lengths, as well as sentences from different corpora. To do this, we will scan the corpora again, consider only the sentences that have a problematic word, and then compute the length of each such sentence.

# %%
from tg.grammar_ru.corpus import BucketBalancer, CorpusReader
from pathlib import Path

buckets_path = Path('tsa-buckets.parquet')

if True or not buckets_path.is_file():
    en = CorpusReader.read_frames_from_several_corpora(corpora).feed(fluq.with_progress_bar()).select(tsa_filter.filter)
    buckets_df = BucketBalancer.collect_buckets(en)
    buckets_df.to_parquet(buckets_path)
else:
    buckets_df = pd.read_parquet(buckets_path)
# Out:
#   0%|          | 0/988 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 buckets_path = Path('tsa-buckets.parquet')
#       6 if True or not buckets_path.is_file():
# ----> 7     en = CorpusReader.read_frames_from_several_corpora(corpora).feed(fluq.with_progress_bar()).select(tsa_filter.filter)
#       8     buckets_df = BucketBalancer.collect_buckets(en)
#       9     buckets_df.to_parquet(buckets_path)
#
# NameError: name 'tsa_filter' is not defined

# %%
from tg.common.analysis import grbar_plot

ax = grbar_plot(
    buckets_df.groupby(['corpus_id','log_len']).size().to_frame('cnt').reset_index(),
    value_column='cnt',
    color_column='corpus_id',
    group_column='log_len'
)
ax.set_yscale('log')
ax.legend()

# %%
import numpy as np
take_df = buckets_df
take_df['random'] = np.random.rand(take_df.shape[0])
take_df = take_df.feed(fluq.add_ordering_column(['corpus_id','log_len'],'random'))
take_df = take_df.loc[(take_df.order<2000) & take_df.log_len.between(2,5)]


ax = grbar_plot(
    take_df.groupby(['corpus_id','log_len']).size().to_frame('cnt').reset_index(),
    value_column='cnt',
    color_column='corpus_id',
    group_column='log_len'
)
ax.legend()

# %% [markdown]
# Let's convert `take_df` into simpler format for `BucketBalancer`, and create a balancer:

# %%
tsa_balancer = BucketBalancer(BucketBalancer.buckets_statistics_to_dict(take_df))
str(tsa_balancer.buckets)[:100]
# Out:
# "{'lenta.base.zip': {5341187, 125894670, 11042843, 72613916, 95715359, 148668449, 147456035, 36044836"

# %% [markdown]
# At this point, we are ready to perform transfusion. Transfusion is an operation that reads the corpora, samples the sentences and creates a new corpus with these selected sentences. Along the way it also correct all the ids, thus making sure the merged corpus is consistant.

# %%
from tg.projects.alternative import AlternativeTaskTransfuseSelector
from tg.grammar_ru.corpus import CorpusBuilder
from tg.common import Logger

Logger.disable()

selector = AlternativeTaskTransfuseSelector(
    tsa_balancer,
    tsa_filter,
    tsa_sampler
)

tsa_transfused = Loc.temp_path/'demos/bundle/tsa.transfused.zip'

CorpusBuilder.transfuse_corpus(
    sources = corpora,
    destination = tsa_transfused,
    selector = selector,
    #words_limit=10000,
    words_per_frame = 10000,
    overwrite = True
)

# %%
from tg.grammar_ru import CorpusReader

CorpusReader(tsa_transfused).get_toc()
# Out:
#                                      filename                  timestamp  \
# file_id
# 081ee02f-b6fe-47c3-b0d7-9cd5f09811c3          2023-07-12 21:24:46.528358
# a3b332cf-872b-41b7-b93e-213a4656e0db          2023-07-12 21:24:49.353324
# 504f3c5b-5ac2-4956-842c-78d65446570f          2023-07-12 21:24:52.557291
# c3bbb02d-e7b7-4426-97f9-4aea4dbe42b7          2023-07-12 21:24:55.716790
# 169db8ac-d5a6-4f99-a23e-91df81027c52          2023-07-12 21:24:59.263487
# 12c9d79c-1fed-43a4-b143-12206f5c3d77          2023-07-12 21:25:02.905351
# d432617a-29fc-4072-8b70-7a0cc8f50292          2023-07-12 21:25:06.070517
# 86f5280d-4897-4af1-a193-11d19991ef14          2023-07-12 21:25:09.577663
# 48751eec-9bc6-490a-b5c8-e6fec882fa8a          2023-07-12 21:25:13.541058
# 9176fe34-15b2-467e-a2e9-7fb28f13e954          2023-07-12 21:25:17.236542
# 33e52835-3a95-410d-b2bd-0a3bb3bffa89          2023-07-12 21:25:20.758560
# 54be3e9f-fc4f-4c32-86ef-dde4bf425c82          2023-07-12 21:25:23.789774
# 0cc1485d-0dca-4005-b199-3044ec4151f0          2023-07-12 21:25:26.805042
# c20c8b00-8a1d-46f5-99c9-15b2a41b4df6          2023-07-12 21:25:30.363822
# c299a58f-9182-43fd-91dd-8ca7b1e75ee6          2023-07-12 21:25:34.144284
# 633c7c43-370a-4246-b771-480e599152a7          2023-07-12 21:25:37.388683
# b35d15e7-b049-43a9-a70e-093bee38460d          2023-07-12 21:25:41.256646
# adf57a04-0722-433e-b859-8a49047a5d6a          2023-07-12 21:25:44.753364
# 7ad10fd8-1aff-44c5-95ce-9d9321ef7380          2023-07-12 21:25:48.250065
# ed4f43e6-8f96-4364-b6e3-c1480479bc3f          2023-07-12 21:25:51.936976
# 00e3ba31-c866-4e0f-8738-031a1f523d28          2023-07-12 21:25:55.079256
# 084ff964-078e-46ac-9a3e-e106245ddd7f          2023-07-12 21:25:58.493884
# 57a3925d-7960-45af-a5af-452febb041f3          2023-07-12 21:26:01.681521
# dcce741b-c7f5-4e12-b680-ebbaa4618baf          2023-07-12 21:26:05.306807
# 84be6c44-d525-4a14-8015-769bfb18bd07          2023-07-12 21:26:08.797629
# 827746ce-de00-4e9e-b986-67979eff9d58          2023-07-12 21:26:11.845096
# 920637c6-686e-4993-8a35-492668857412          2023-07-12 21:26:15.424533
# 88407c99-474f-46f5-90c7-766e6443aea7          2023-07-12 21:26:18.710582
# 24886698-c875-49de-b8de-5d45b1dcfb14          2023-07-12 21:26:22.549611
# e3a181f1-2493-4f02-af3b-bcfc5936287c          2023-07-12 21:26:25.496766
# 5b6c21f1-ed5c-4425-99c9-a460c6807848          2023-07-12 21:26:28.971571
# 0fe9ce0c-e2e5-4a22-8835-f886dc6a0491          2023-07-12 21:26:32.173365
# 075d7902-008f-4b7f-9263-eebe93c7217b          2023-07-12 21:26:34.956805
#
#                                       part_index  token_count  \
# file_id
# 081ee02f-b6fe-47c3-b0d7-9cd5f09811c3           0         9945
# a3b332cf-872b-41b7-b93e-213a4656e0db           1         9994
# 504f3c5b-5ac2-4956-842c-78d65446570f           2         9998
# c3bbb02d-e7b7-4426-97f9-4aea4dbe42b7           3         9988
# 169db8ac-d5a6-4f99-a23e-91df81027c52           4         9984
# 12c9d79c-1fed-43a4-b143-12206f5c3d77           5         9972
# d432617a-29fc-4072-8b70-7a0cc8f50292           6         9972
# 86f5280d-4897-4af1-a193-11d19991ef14           7         9979
# 48751eec-9bc6-490a-b5c8-e6fec882fa8a           8         9999
# 9176fe34-15b2-467e-a2e9-7fb28f13e954           9         9965
# 33e52835-3a95-410d-b2bd-0a3bb3bffa89          10         9995
# 54be3e9f-fc4f-4c32-86ef-dde4bf425c82          11         9979
# 0cc1485d-0dca-4005-b199-3044ec4151f0          12         9984
# c20c8b00-8a1d-46f5-99c9-15b2a41b4df6          13         9975
# c299a58f-9182-43fd-91dd-8ca7b1e75ee6          14         9956
# 633c7c43-370a-4246-b771-480e599152a7          15         9988
# b35d15e7-b049-43a9-a70e-093bee38460d          16         9987
# adf57a04-0722-433e-b859-8a49047a5d6a          17         9997
# 7ad10fd8-1aff-44c5-95ce-9d9321ef7380          18         9995
# ed4f43e6-8f96-4364-b6e3-c1480479bc3f          19         9965
# 00e3ba31-c866-4e0f-8738-031a1f523d28          20         9982
# 084ff964-078e-46ac-9a3e-e106245ddd7f          21         9979
# 57a3925d-7960-45af-a5af-452febb041f3          22         9987
# dcce741b-c7f5-4e12-b680-ebbaa4618baf          23         9979
# 84be6c44-d525-4a14-8015-769bfb18bd07          24         9981
# 827746ce-de00-4e9e-b986-67979eff9d58          25         9997
# 920637c6-686e-4993-8a35-492668857412          26         9988
# 88407c99-474f-46f5-90c7-766e6443aea7          27         9999
# 24886698-c875-49de-b8de-5d45b1dcfb14          28         9975
# e3a181f1-2493-4f02-af3b-bcfc5936287c          29         9979
# 5b6c21f1-ed5c-4425-99c9-a460c6807848          30         9981
# 0fe9ce0c-e2e5-4a22-8835-f886dc6a0491          31         9996
# 075d7902-008f-4b7f-9263-eebe93c7217b          32         9331
#
#                                       character_count  ordinal  max_id
# file_id
# 081ee02f-b6fe-47c3-b0d7-9cd5f09811c3            52147        0   10683
# a3b332cf-872b-41b7-b93e-213a4656e0db            52101        1   21260
# 504f3c5b-5ac2-4956-842c-78d65446570f            52806        2   31951
# c3bbb02d-e7b7-4426-97f9-4aea4dbe42b7            53129        3   42610
# 169db8ac-d5a6-4f99-a23e-91df81027c52            52483        4   53331
# 12c9d79c-1fed-43a4-b143-12206f5c3d77            53908        5   64084
# d432617a-29fc-4072-8b70-7a0cc8f50292            52300        6   74738
# 86f5280d-4897-4af1-a193-11d19991ef14            53834        7   85520
# 48751eec-9bc6-490a-b5c8-e6fec882fa8a            53222        8   96377
# 9176fe34-15b2-467e-a2e9-7fb28f13e954            53336        9  107090
# 33e52835-3a95-410d-b2bd-0a3bb3bffa89            52881       10  117844
# 54be3e9f-fc4f-4c32-86ef-dde4bf425c82            52759       11  128439
# 0cc1485d-0dca-4005-b199-3044ec4151f0            54341       12  139039
# c20c8b00-8a1d-46f5-99c9-15b2a41b4df6            52437       13  149751
# c299a58f-9182-43fd-91dd-8ca7b1e75ee6            51813       14  160488
# 633c7c43-370a-4246-b771-480e599152a7            52505       15  171158
# b35d15e7-b049-43a9-a70e-093bee38460d            52618       16  181970
# adf57a04-0722-433e-b859-8a49047a5d6a            52820       17  192671
# 7ad10fd8-1aff-44c5-95ce-9d9321ef7380            53359       18  203403
# ed4f43e6-8f96-4364-b6e3-c1480479bc3f            52777       19  214149
# 00e3ba31-c866-4e0f-8738-031a1f523d28            54031       20  224780
# 084ff964-078e-46ac-9a3e-e106245ddd7f            52484       21  235496
# 57a3925d-7960-45af-a5af-452febb041f3            52422       22  246143
# dcce741b-c7f5-4e12-b680-ebbaa4618baf            53430       23  256881
# 84be6c44-d525-4a14-8015-769bfb18bd07            53440       24  267610
# 827746ce-de00-4e9e-b986-67979eff9d58            52978       25  278256
# 920637c6-686e-4993-8a35-492668857412            53166       26  288981
# 88407c99-474f-46f5-90c7-766e6443aea7            53140       27  299706
# 24886698-c875-49de-b8de-5d45b1dcfb14            53425       28  310473
# e3a181f1-2493-4f02-af3b-bcfc5936287c            53508       29  321079
# 5b6c21f1-ed5c-4425-99c9-a460c6807848            52769       30  331775
# 0fe9ce0c-e2e5-4a22-8835-f886dc6a0491            51685       31  342431
# 075d7902-008f-4b7f-9263-eebe93c7217b            49421       32  352356

# %%
CorpusReader(tsa_transfused).get_frames().first().head()
# Out:
#    word_id  sentence_id  word_index  paragraph_id  word_tail        word  \
# 0        0            0           0             0          1       Акция
# 1        1            0           1             0          1  проводится
# 2        2            0           2             0          1         под
# 3        3            0           3             0          1    хештегом
# 4        4            0           4             0          0           #
#
#   word_type  word_length                               file_id  \
# 0        ru            5  081ee02f-b6fe-47c3-b0d7-9cd5f09811c3
# 1        ru           10  081ee02f-b6fe-47c3-b0d7-9cd5f09811c3
# 2        ru            3  081ee02f-b6fe-47c3-b0d7-9cd5f09811c3
# 3        ru            8  081ee02f-b6fe-47c3-b0d7-9cd5f09811c3
# 4       unk            1  081ee02f-b6fe-47c3-b0d7-9cd5f09811c3
#
#             corpus_id  is_target  label original_corpus  original_word_id  \
# 0  tsa.transfused.zip      False      0  lenta.base.zip             63561
# 1  tsa.transfused.zip       True      0  lenta.base.zip             63562
# 2  tsa.transfused.zip      False      0  lenta.base.zip             63563
# 3  tsa.transfused.zip      False      0  lenta.base.zip             63564
# 4  tsa.transfused.zip      False      0  lenta.base.zip             63565
#
#    original_sentence_id  original_paragraph_id  updated
# 0                  3406                    630    False
# 1                  3406                    630    False
# 2                  3406                    630    False
# 3                  3406                    630    False
# 4                  3406                    630    False

# %% [markdown]
# The next step is to enrich the corpus with features. This can also be done with `CorpusBuilder`:

# %%
from tg.grammar_ru.features import PyMorphyFeaturizer, SnowballFeaturizer

tsa_featurized = Loc.temp_path/'demos/bundle/tsa.featurized.zip'

CorpusBuilder.featurize_corpus(
    tsa_transfused,
    tsa_featurized,
    [PyMorphyFeaturizer(), SnowballFeaturizer()]
)

# %% [markdown]
# Now we have all the information in the corpus format. We need to assemble this in bundle format: concatenate all the separate frames from `src`, `pymorphy` and other frames:

# %%
tsa_bundle = Loc.temp_path/'demos/bundle/bundle'
CorpusBuilder.assemble(
    tsa_featurized,
    tsa_bundle
)
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]

# %% [markdown]
# And finally, we need to create an index frame. This is usually just a subset of `src` frame:

# %%
index_frame = pd.read_parquet(tsa_bundle/'src.parquet')
index_frame = index_frame.loc[index_frame.is_target][['word_id','sentence_id','label']].reset_index(drop=True)
index_frame.index.name = 'sample_id'
index_frame.to_parquet(tsa_bundle/'index.parquet')
index_frame.head()
# Out:
#            word_id  sentence_id  label
# sample_id
# 0                1            0      0
# 1               22            1      0
# 2               35            1      0
# 3               51            2      0
# 4               80           79      1

# %%
from tg.common import DataBundle
old_path = Loc.tg_path/'common/test_common/test_ml_integration/tsa-test.zip'
old_db = DataBundle.load(old_path)
new_db = DataBundle.load(tsa_bundle)
print(old_db.index.shape, old_db.src.shape)
print(new_db.index.shape, new_db.src.shape)
# Out:
# (17530, 4) (176600, 16)
# (16368, 3) (328771, 17)

# %%
new_path_1 = Loc.temp_path/'test-bundle-1.zip'
new_db.save_as_zip(new_path_1)

# %%
os.stat(new_path_1).st_size//1000000, os.stat(old_path).st_size//1000000
# Out:
# (6, 3)

# %%
new_db['src'] = new_db.src[['word_id','sentence_id','word_index','paragraph_id','word_tail','word']]
new_db['snowball'] = new_db.snowball[['stem','ending']]
new_db['pymorphy'] = new_db.pymorphy.drop('normal_form', axis=1)
new_path_2 = Loc.temp_path/'test-bundle-2.zip'
new_db.save_as_zip(new_path_2)

# %%
os.stat(new_path_1).st_size//1000000, os.stat(new_path_2).st_size//1000000,  os.stat(old_path).st_size//1000000
# Out:
# (6, 4, 3)
