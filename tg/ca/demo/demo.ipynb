# %% [markdown]
# # Creative Articulator
#
# ## Overview

# %% [markdown]
# In this demo, we will look at all the processes in Creative Articulator namely:
#  - the creation of a parallel corpus
#  - the division of text into fragments
#  - translation of text.

# %% [markdown]
# ## Parallel corpus
#
# A parallel corpus is a handy tool that allows you to link parts from different corpus. With it, all the corpus will be stored in a single zip file.
#
# In this demonstration, we will work with texts and retellings of Fyodor Mikhailovich Dostoevsky's novel Crime and Punishment, which are located in the `sourse` folder.
#
#
# The first step is to create a corpus of texts and retellings that are stored in md format.

# %% [markdown]
# #### Сorpus for English text:

# %%
from tg.grammar_ru.corpus import CorpusBuilder
from pathlib import Path


CorpusBuilder.convert_interformat_folder_to_corpus(
    Path('./files/eng_crime_and_puhishment.base.zip'),
    Path('./source/book/eng'),
    ['book']
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from tg.grammar_ru.corpus import CorpusReader


eng_book_reader = CorpusReader(Path('./files/eng_crime_and_puhishment.base.zip'))
eng_book = eng_book_reader.get_toc().index

eng_book_reader.get_toc()
# Out:
#                                                          filename  \
# file_id
# b7055445-59df-455d-878a-7e948471fd72  eng_crime_and_punishment.md
# d96af6af-df0a-4598-b542-a29b95c260ea  eng_crime_and_punishment.md
# 20365fe7-b4b7-46f2-a65b-26c5bbb8810f  eng_crime_and_punishment.md
# aec9ab96-9f67-493c-b873-f289ed76e349  eng_crime_and_punishment.md
# 9a9c35eb-5fa8-44ff-afe8-e9981b041bd8  eng_crime_and_punishment.md
# 80c2206d-fdd6-41b2-91d0-4e417611f1be  eng_crime_and_punishment.md
# 64ca7a69-e839-4553-94ff-dd7e7579c5d1  eng_crime_and_punishment.md
#
#                                                       timestamp  part_index  \
# file_id
# b7055445-59df-455d-878a-7e948471fd72 2023-12-13 00:09:53.864682           0
# d96af6af-df0a-4598-b542-a29b95c260ea 2023-12-13 00:09:53.904472           1
# 20365fe7-b4b7-46f2-a65b-26c5bbb8810f 2023-12-13 00:09:53.951774           2
# aec9ab96-9f67-493c-b873-f289ed76e349 2023-12-13 00:09:53.992332           3
# 9a9c35eb-5fa8-44ff-afe8-e9981b041bd8 2023-12-13 00:09:54.033009           4
# 80c2206d-fdd6-41b2-91d0-4e417611f1be 2023-12-13 00:09:54.065175           5
# 64ca7a69-e839-4553-94ff-dd7e7579c5d1 2023-12-13 00:09:54.100632           6
#
#                                       token_count  character_count  ordinal  \
# file_id
# b7055445-59df-455d-878a-7e948471fd72         3967            14847        0
# d96af6af-df0a-4598-b542-a29b95c260ea         8814            32455        1
# 20365fe7-b4b7-46f2-a65b-26c5bbb8810f         6450            24138        2
# aec9ab96-9f67-493c-b873-f289ed76e349         6277            22584        3
# 9a9c35eb-5fa8-44ff-afe8-e9981b041bd8         5101            18685        4
# 80c2206d-fdd6-41b2-91d0-4e417611f1be         5879            22359        5
# 64ca7a69-e839-4553-94ff-dd7e7579c5d1         5845            21214        6
#
#                                          header_0      headers  \
# file_id
# b7055445-59df-455d-878a-7e948471fd72    CHAPTER I    CHAPTER I
# d96af6af-df0a-4598-b542-a29b95c260ea   CHAPTER II   CHAPTER II
# 20365fe7-b4b7-46f2-a65b-26c5bbb8810f  CHAPTER III  CHAPTER III
# aec9ab96-9f67-493c-b873-f289ed76e349   CHAPTER IV   CHAPTER IV
# 9a9c35eb-5fa8-44ff-afe8-e9981b041bd8    CHAPTER V    CHAPTER V
# 80c2206d-fdd6-41b2-91d0-4e417611f1be   CHAPTER VI   CHAPTER VI
# 64ca7a69-e839-4553-94ff-dd7e7579c5d1  CHAPTER VII  CHAPTER VII
#
#                                                           book  max_id
# file_id
# b7055445-59df-455d-878a-7e948471fd72  eng_crime_and_punishment    3968
# d96af6af-df0a-4598-b542-a29b95c260ea  eng_crime_and_punishment   22783
# 20365fe7-b4b7-46f2-a65b-26c5bbb8810f  eng_crime_and_punishment   39234
# aec9ab96-9f67-493c-b873-f289ed76e349  eng_crime_and_punishment   55512
# 9a9c35eb-5fa8-44ff-afe8-e9981b041bd8  eng_crime_and_punishment   70614
# 80c2206d-fdd6-41b2-91d0-4e417611f1be  eng_crime_and_punishment   86494
# 64ca7a69-e839-4553-94ff-dd7e7579c5d1  eng_crime_and_punishment  102340

# %% [markdown]
# #### Corpus for English retelling:

# %%
CorpusBuilder.convert_interformat_folder_to_corpus(
    Path('./files/eng_retell.base.zip'),
    Path('./source/retell/eng'),
    ['book']
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
eng_retell_reader = CorpusReader(Path('./files/eng_retell.base.zip'))
eng_retell = eng_retell_reader.get_toc().index
eng_retell_reader.get_toc()
# Out:
#                                            filename  \
# file_id
# e226242e-9e63-4301-99ba-7305a4fc6b6a  eng_retell.md
# 89d065bc-0f63-4ccb-a26c-1b62b2cf984e  eng_retell.md
# 4161f58d-10a3-4f9d-b465-14cbdd5630b6  eng_retell.md
# a4423f48-e762-4cb9-9026-68fd8dec61b2  eng_retell.md
# ddfcc6df-bcf3-4168-9f33-012b7de9b9ae  eng_retell.md
# b69770f3-5011-43f9-ac40-eb79c0eadf2a  eng_retell.md
# ab6a2a4a-59ee-4dea-bd7f-a6df65a9a4ff  eng_retell.md
#
#                                                       timestamp  part_index  \
# file_id
# e226242e-9e63-4301-99ba-7305a4fc6b6a 2023-12-13 00:09:54.809917           0
# 89d065bc-0f63-4ccb-a26c-1b62b2cf984e 2023-12-13 00:09:54.815929           1
# 4161f58d-10a3-4f9d-b465-14cbdd5630b6 2023-12-13 00:09:54.844945           2
# a4423f48-e762-4cb9-9026-68fd8dec61b2 2023-12-13 00:09:54.864124           3
# ddfcc6df-bcf3-4168-9f33-012b7de9b9ae 2023-12-13 00:09:54.883370           4
# b69770f3-5011-43f9-ac40-eb79c0eadf2a 2023-12-13 00:09:54.906257           5
# ab6a2a4a-59ee-4dea-bd7f-a6df65a9a4ff 2023-12-13 00:09:54.927357           6
#
#                                       token_count  character_count  ordinal  \
# file_id
# e226242e-9e63-4301-99ba-7305a4fc6b6a          782             3092        0
# 89d065bc-0f63-4ccb-a26c-1b62b2cf984e          783             3274        1
# 4161f58d-10a3-4f9d-b465-14cbdd5630b6          729             3015        2
# a4423f48-e762-4cb9-9026-68fd8dec61b2          739             2927        3
# ddfcc6df-bcf3-4168-9f33-012b7de9b9ae          917             3598        4
# b69770f3-5011-43f9-ac40-eb79c0eadf2a         1024             4168        5
# ab6a2a4a-59ee-4dea-bd7f-a6df65a9a4ff         1030             4085        6
#
#                                         header_0     headers        book  \
# file_id
# e226242e-9e63-4301-99ba-7305a4fc6b6a  Chapter 1:  Chapter 1:  eng_retell
# 89d065bc-0f63-4ccb-a26c-1b62b2cf984e  Chapter 2:  Chapter 2:  eng_retell
# 4161f58d-10a3-4f9d-b465-14cbdd5630b6  Chapter 3:  Chapter 3:  eng_retell
# a4423f48-e762-4cb9-9026-68fd8dec61b2  Chapter 4:  Chapter 4:  eng_retell
# ddfcc6df-bcf3-4168-9f33-012b7de9b9ae  Chapter 5:  Chapter 5:  eng_retell
# b69770f3-5011-43f9-ac40-eb79c0eadf2a  Chapter 6:  Chapter 6:  eng_retell
# ab6a2a4a-59ee-4dea-bd7f-a6df65a9a4ff  Chapter 7:  Chapter 7:  eng_retell
#
#                                       max_id
# file_id
# e226242e-9e63-4301-99ba-7305a4fc6b6a     783
# 89d065bc-0f63-4ccb-a26c-1b62b2cf984e   11567
# 4161f58d-10a3-4f9d-b465-14cbdd5630b6   22297
# a4423f48-e762-4cb9-9026-68fd8dec61b2   33037
# ddfcc6df-bcf3-4168-9f33-012b7de9b9ae   43955
# b69770f3-5011-43f9-ac40-eb79c0eadf2a   54980
# ab6a2a4a-59ee-4dea-bd7f-a6df65a9a4ff   66011

# %% [markdown]
# #### Сorpus for Russian text:

# %%
CorpusBuilder.convert_interformat_folder_to_corpus(
    Path('./files/ru_crime_and_puhishment.base.zip'),
    Path('./source/book/ru'),
    ['book']
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ru_book_reader = CorpusReader(Path('./files/ru_crime_and_puhishment.base.zip'))
ru_book = ru_book_reader.get_toc().index
ru_book_reader.get_toc()
# Out:
#                                                         filename  \
# file_id
# ab086fe8-1d08-4893-9186-131a7779242a  ru_crime_and_punishment.md
# 4ed0e637-0596-4818-8b9e-ceada091df77  ru_crime_and_punishment.md
# f25e25d7-3e5e-456b-88f4-6035f59bf95a  ru_crime_and_punishment.md
# 69cb43e3-2227-4642-9a18-858d4feeeff4  ru_crime_and_punishment.md
# d8a2d97f-1d1c-4979-bae2-7f52a2855295  ru_crime_and_punishment.md
# 166e72e7-93ab-4a36-8065-7ffb32ec1f6b  ru_crime_and_punishment.md
# 22aa3c8a-efc4-441e-8448-d103a26cea77  ru_crime_and_punishment.md
#
#                                                       timestamp  part_index  \
# file_id
# ab086fe8-1d08-4893-9186-131a7779242a 2023-12-13 00:09:59.058522           0
# 4ed0e637-0596-4818-8b9e-ceada091df77 2023-12-13 00:09:59.068368           1
# f25e25d7-3e5e-456b-88f4-6035f59bf95a 2023-12-13 00:09:59.117051           2
# 69cb43e3-2227-4642-9a18-858d4feeeff4 2023-12-13 00:09:59.154774           3
# d8a2d97f-1d1c-4979-bae2-7f52a2855295 2023-12-13 00:09:59.189485           4
# 166e72e7-93ab-4a36-8065-7ffb32ec1f6b 2023-12-13 00:09:59.218925           5
# 22aa3c8a-efc4-441e-8448-d103a26cea77 2023-12-13 00:09:59.254320           6
#
#                                       token_count  character_count  ordinal  \
# file_id
# ab086fe8-1d08-4893-9186-131a7779242a         3243            13794        0
# 4ed0e637-0596-4818-8b9e-ceada091df77         7122            29354        1
# f25e25d7-3e5e-456b-88f4-6035f59bf95a         5526            22716        2
# 69cb43e3-2227-4642-9a18-858d4feeeff4         5231            21068        3
# d8a2d97f-1d1c-4979-bae2-7f52a2855295         4285            17317        4
# 166e72e7-93ab-4a36-8065-7ffb32ec1f6b         5118            21335        5
# 22aa3c8a-efc4-441e-8448-d103a26cea77         4851            19153        6
#
#                                      header_0 headers  \
# file_id
# ab086fe8-1d08-4893-9186-131a7779242a        I       I
# 4ed0e637-0596-4818-8b9e-ceada091df77       II      II
# f25e25d7-3e5e-456b-88f4-6035f59bf95a      III     III
# 69cb43e3-2227-4642-9a18-858d4feeeff4       IV      IV
# d8a2d97f-1d1c-4979-bae2-7f52a2855295        V       V
# 166e72e7-93ab-4a36-8065-7ffb32ec1f6b       VI      VI
# 22aa3c8a-efc4-441e-8448-d103a26cea77      VII     VII
#
#                                                          book  max_id
# file_id
# ab086fe8-1d08-4893-9186-131a7779242a  ru_crime_and_punishment    3244
# 4ed0e637-0596-4818-8b9e-ceada091df77  ru_crime_and_punishment   20367
# f25e25d7-3e5e-456b-88f4-6035f59bf95a  ru_crime_and_punishment   35894
# 69cb43e3-2227-4642-9a18-858d4feeeff4  ru_crime_and_punishment   51126
# d8a2d97f-1d1c-4979-bae2-7f52a2855295  ru_crime_and_punishment   65412
# 166e72e7-93ab-4a36-8065-7ffb32ec1f6b  ru_crime_and_punishment   80531
# 22aa3c8a-efc4-441e-8448-d103a26cea77  ru_crime_and_punishment   95383

# %% [markdown]
# #### Corpus for Russian retelling:

# %%
CorpusBuilder.convert_interformat_folder_to_corpus(
    Path('./files/ru_retell.base.zip'),
    Path('./source/retell/ru'),
    ['book']
    )
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ru_retell_reader = CorpusReader(Path('./files/ru_retell.base.zip'))
ru_retell = ru_retell_reader.get_toc().index
ru_retell_reader.get_toc()
# Out:
#                                           filename                  timestamp  \
# file_id
# bc3689ae-2bb2-41ee-b921-3628c9874897  ru_retell.md 2023-12-13 00:09:59.753402
# 36af7964-be60-418c-b8b8-56d4a831db0a  ru_retell.md 2023-12-13 00:09:59.759926
# 98f07874-d59a-4447-a93a-047d57e6c97b  ru_retell.md 2023-12-13 00:09:59.779023
# bb703c1d-d01d-4dc9-ab22-2b5da731f2a4  ru_retell.md 2023-12-13 00:09:59.793552
# 02920f70-554c-49f5-b161-d2e386536827  ru_retell.md 2023-12-13 00:09:59.809880
# 3215e61a-366b-48f1-be76-33a2a7fb9af5  ru_retell.md 2023-12-13 00:09:59.825753
# 084e4ff3-6ad7-41cc-bef2-7dfab639ca7b  ru_retell.md 2023-12-13 00:09:59.843353
#
#                                       part_index  token_count  \
# file_id
# bc3689ae-2bb2-41ee-b921-3628c9874897           0          396
# 36af7964-be60-418c-b8b8-56d4a831db0a           1          704
# 98f07874-d59a-4447-a93a-047d57e6c97b           2          280
# bb703c1d-d01d-4dc9-ab22-2b5da731f2a4           3          461
# 02920f70-554c-49f5-b161-d2e386536827           4          193
# 3215e61a-366b-48f1-be76-33a2a7fb9af5           5          330
# 084e4ff3-6ad7-41cc-bef2-7dfab639ca7b           6          308
#
#                                       character_count  ordinal  \
# file_id
# bc3689ae-2bb2-41ee-b921-3628c9874897             1814        0
# 36af7964-be60-418c-b8b8-56d4a831db0a             3090        1
# 98f07874-d59a-4447-a93a-047d57e6c97b             1330        2
# bb703c1d-d01d-4dc9-ab22-2b5da731f2a4             2020        3
# 02920f70-554c-49f5-b161-d2e386536827              892        4
# 3215e61a-366b-48f1-be76-33a2a7fb9af5             1457        5
# 084e4ff3-6ad7-41cc-bef2-7dfab639ca7b             1383        6
#
#                                                              header_0  \
# file_id
# bc3689ae-2bb2-41ee-b921-3628c9874897   Глава 1: Знакомство с Родионом
# 36af7964-be60-418c-b8b8-56d4a831db0a  Глава 2: Встреча с Мармеладовым
# 98f07874-d59a-4447-a93a-047d57e6c97b           Глава 3: Письмо матери
# bb703c1d-d01d-4dc9-ab22-2b5da731f2a4          Глава 4: Мысли о сестре
# 02920f70-554c-49f5-b161-d2e386536827       Глава 5: Сон Раскольникова
# 3215e61a-366b-48f1-be76-33a2a7fb9af5   Глава 6: Подготовка к убийству
# 084e4ff3-6ad7-41cc-bef2-7dfab639ca7b            Глава 7: Преступление
#
#                                                               headers  \
# file_id
# bc3689ae-2bb2-41ee-b921-3628c9874897   Глава 1: Знакомство с Родионом
# 36af7964-be60-418c-b8b8-56d4a831db0a  Глава 2: Встреча с Мармеладовым
# 98f07874-d59a-4447-a93a-047d57e6c97b           Глава 3: Письмо матери
# bb703c1d-d01d-4dc9-ab22-2b5da731f2a4          Глава 4: Мысли о сестре
# 02920f70-554c-49f5-b161-d2e386536827       Глава 5: Сон Раскольникова
# 3215e61a-366b-48f1-be76-33a2a7fb9af5   Глава 6: Подготовка к убийству
# 084e4ff3-6ad7-41cc-bef2-7dfab639ca7b            Глава 7: Преступление
#
#                                            book  max_id
# file_id
# bc3689ae-2bb2-41ee-b921-3628c9874897  ru_retell     397
# 36af7964-be60-418c-b8b8-56d4a831db0a  ru_retell   11102
# 98f07874-d59a-4447-a93a-047d57e6c97b  ru_retell   21383
# bb703c1d-d01d-4dc9-ab22-2b5da731f2a4  ru_retell   31845
# 02920f70-554c-49f5-b161-d2e386536827  ru_retell   42039
# 3215e61a-366b-48f1-be76-33a2a7fb9af5  ru_retell   52370
# 084e4ff3-6ad7-41cc-bef2-7dfab639ca7b  ru_retell   62679

# %% [markdown]
# Next, we form a parallel corpus

# %%
import pandas as pd

def add_relation(df_1,df_2,name_1,name_2):
    rel_1 = {'file_1':df_1, 'file_2':df_2,'relation_name':f"{name_1}_{name_2}"}
    rel_2 = {'file_1':df_2, 'file_2':df_1,'relation_name':f"{name_2}_{name_1}"}
    rel = pd.concat([rel_1,rel_2])
    return rel

def add_dfs(name):
    frames = list(name.get_frames())
    dfs = dict(zip(name.get_toc().index,frames))

    return dfs

# %%
CorpusBuilder.update_parallel_data(
    Path('./files/parallel_corpus.zip'),
    add_dfs(ru_book_reader),
    "ru_book",
    None)

CorpusBuilder.update_parallel_data(
    Path('./files/parallel_corpus.zip'),
    add_dfs(ru_retell_reader),
    "ru_retell",
    None)

CorpusBuilder.update_parallel_data(
    Path('./files/parallel_corpus.zip'),
    add_dfs(eng_retell_reader),
    "eng_retell",
    None)

CorpusBuilder.update_parallel_data(
    Path('./files/parallel_corpus.zip'),
    add_dfs(eng_book_reader),
    "eng_book",
    None)

# %% [markdown]
# We check that all parts have been successfully recorded

# %%
reader = CorpusReader(Path('./files/parallel_corpus.zip'))

df = reader.get_toc()

df.subcorpus_name.unique()
# Out:
# array(['ru_book', 'ru_retell', 'eng_retell', 'eng_book'], dtype=object)

# %% [markdown]
# ## Text fragmentation

# %%
from tg.grammar_ru.corpus import ParallelCorpus
parallel_corpus = ParallelCorpus(Path('./files/parallel_corpus.zip'))

# %% [markdown]
# Creating fragments (json/corpus)

# %%
from tg.projects.book_tasks.fragments_builder import FragmentsBuilder


fragments_builder = FragmentsBuilder(parallel_corpus.eng_book, file_name="cip_fragments")
fragments_builder.construct_fragments_json()
fragments_builder.construct_fragments_corpus()
# Out:
# Processing frame with id: 979f5f5f-7666-469d-9d4e-fd201e4f2c54, 2/21

# %%
cip_fragments_corpus = Path('./files/cip_fragments.base.zip')
cip_fragments_reader = CorpusReader(cip_fragments_corpus)

cip_fragments_reader.get_frames().first()
# Out:
#                                      id                               file_id  \
# 0  0f564806-9922-11ee-8277-c3d46d71b757  ce85eaf2-b096-49b6-ab5c-e130c4e42e48
#
#    word  word_length                                             prompt  \
# 0     0            0  retell this text in simple sentences and simpl...
#
#                                       text_narrative  \
# 0  —and in one moment the brain is stronger, the ...
#
#                                          text_dialog retell  word_start_id  \
# 0  “His wife a year he fondly loved“Walking along...                257674
#
#    word_end_id  word_id  sentence_id  paragraph_id               corpus_id
# 0       254221        1            1             1  cip_fragments.base.zip

# %% [markdown]
# ### Translate text

# %%
from tg.projects.retell.translate.utils import get_array_chapters

ru_retell_text = get_array_chapters(parallel_corpus.ru_retell)
eng_retell_text = get_array_chapters(parallel_corpus.eng_retell)
ru_book_text = get_array_chapters(parallel_corpus.ru_book)


print(ru_book_text[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 4
#       1 from tg.projects.retell.translate.utils import get_array_chapters
#       3 ru_retell_text = get_array_chapters(parallel_corpus.ru_retell)
# ----> 4 eng_retell_text = get_array_chapters(eng_retell_reader.eng_retell)
#       5 ru_book_text = get_array_chapters(ru_book_reader.ru_book)
#       8 print(eng_book_text[0])
#
# AttributeError: 'CorpusReader' object has no attribute 'eng_retell'

# %%
from tg.projects.retell.translate.utils import translate
translate_retell = translate(eng_retell_text)
print(translate_retell[0])
# Out:
# В Санкт-Петербурге начало июля.
# В Петербурге очень жарко.
# Симпатичному молодому человеку, почти нищему и сильно обязанному своей хозяйке, удается незаметно выскользнуть из дома.
# Он испытывает облегчение не потому, что он трус по натуре, а потому, что с некоторых пор он раздражителен и напряжен и боится вообще с кем-либо встречаться, не говоря уже о своей хозяйке.
# Молодой человек быстро и бессвязно думает о каком-то неизвестном поступке, о совершении которого он, кажется, рвется.
# С одной стороны, он хочет это сделать, но с другой, он пытается убедить себя, что он просто играет с идеей и несерьезно претворяет ее в жизнь.
# Юношу раздражает жара и вонь окружающей среды, но он теряется в своих мыслях, которые иногда путаются, поскольку он почти ничего не ел за два дня.
# Его выводит из задумчивости пьяный, выкрикивающий оскорбления в адрес его шляпы.
# Внезапно испугавшись, он хватается за шляпу и лихорадочно бормочет про себя, что шляпа слишком бросается в глаза и ее можно «заметить... и запомнить» как доказательство.
# Он приближается к дому, где ему предстоит «испытать свое начинание» (т. е. неизвестное дело, терзающее его разум).
# Он поднимается по черной лестнице на четвертый этаж, замечая, что один из жильцов этого этажа съезжает, так что «на время только квартира старухи останется занятой».
# Это хорошо... на всякий случай...", - думает он, прежде чем позвонить в колокольчик.
# Дверь открывает подозрительная шестидесятилетняя женщина, которая недоверчиво впускает его.
# Молодой человек представляется как «Раскольников-студент», бывавший у нее месяц назад.
# Женщина вспоминает о нем и позволяет ему пройти в другую комнату.
# Со свойственной ему сверхсознательностью Раскольников подмечает каждую деталь безупречной комнаты и ее мебели.
# Оказывается, эта старушка, Алена Ивановна, ростовщица, и Раскольников месяц тому назад ходил к ней с отцовским кольцом.
# Срок его залога истек, но он умоляет ее набраться терпения и дарит ей старые часы.
# Он просит четыре рубля; она предлагает полтора с предоплатой процентов.
# Раскольников возмущен, но другого выхода у него нет и, вспомнив о своей первоначальной цели «суда», неохотно принимает ее предложение.
# Он смотрит, как Алена Ивановна достает ключи и уходит в другую комнату.
# Пока он ждет, он слушает и выясняет, что она делает: открывает верхний ящик, каким ключом и т. д.
# Она возвращается с его деньгами, вычитая проценты не только из текущего залога, но и из предыдущего, так что он получает только один рубль 15 копеек.
# Раскольников не спорит, берет деньги и бормочет что-то о том, чтобы потом принести ей красивый серебряный портсигар.
# Выходя, он небрежно спрашивает, остается ли она дома одна, без сестры, но получает только подозрительный вопрос.
# Он уходит так быстро, как только может, чувствуя себя встревоженным, и его волнение нарастает, пока посреди улицы он не вырывается с недоверием о своем созерцании «такого ужаса», который преследовал его мысли в течение месяца.
# Однако эта вспышка не приносит ему облегчения и неровно плетется по улице, пока он не приходит в себя возле таверны.
# Он тут же входит, внезапно осознав, насколько он слаб от голода и жажды.
# Выпивая холодное пиво, он чувствует облегчение и начинает мыслить более рационально, пытаясь сказать себе, что ему нужно лишь немного подкрепиться и что на самом деле беспокоиться не о чем.
# Однако он чувствует смутное предчувствие, что его жизнерадостность столь же болезненна, как и его предыдущее состояние.
# Людей в таверне немного: торговец, его друг, который задремал и время от времени просыпается, чтобы спеть какую-нибудь сентиментальную мелодию, и кто-то, похожий на отставного чиновника и выглядящий взволнованным.

# %%
from tg.projects.retell.retell_utils.metrics import get_jaccard_index
from tg.projects.retell.translate.utils import jac_metric
import numpy as np



jaccard_sim = np.array([get_jaccard_index(ru_book_text[i],ru_retell_text[i]) for i in range(len(ru_retell_text))])
jac_metric(jaccard_sim)

# %%
jaccard_sim = np.array([get_jaccard_index(ru_book_text[i],translate_retell[i]) for i in range(len(ru_retell_text))])
jac_metric(jaccard_sim)

# %%
from yo_fluq_ds import FileIO

result = ''

for text in translate_retell:
    result += "\n## part\n"

    result += text


FileIO.write_text(result, Path("./source/translate/translate.md"))

# %%
CorpusBuilder.convert_interformat_folder_to_corpus(
    Path('./files/translate.base.zip'),
    Path('./source/translate'),
    ['book']
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ru_retell_reader = CorpusReader(Path('./files/translate.base.zip'))
ru_retell_reader.get_toc()
# Out:
#                                           filename                  timestamp  \
# file_id
# 6d783b84-c913-467e-b051-4454582f70e0  translate.md 2023-12-13 00:10:16.946099
# 2943c186-fb4c-4fa2-a4e4-a08701b33fc4  translate.md 2023-12-13 00:10:16.950667
# 783cbd98-a3dd-488c-8efc-a6806f49aef8  translate.md 2023-12-13 00:10:16.975799
# 6c9f8347-d76a-491e-8e5a-96c279089363  translate.md 2023-12-13 00:10:16.996119
# b92d3375-d907-414e-b45f-3169361e2e36  translate.md 2023-12-13 00:10:17.014719
# bf08b5ad-ab60-4063-9e33-da305294a802  translate.md 2023-12-13 00:10:17.034510
# f1d7450e-d921-4d17-857c-2b2cbc98f569  translate.md 2023-12-13 00:10:17.056704
#
#                                       part_index  token_count  \
# file_id
# 6d783b84-c913-467e-b051-4454582f70e0           0          667
# 2943c186-fb4c-4fa2-a4e4-a08701b33fc4           1          665
# 783cbd98-a3dd-488c-8efc-a6806f49aef8           2          620
# 6c9f8347-d76a-491e-8e5a-96c279089363           3          612
# b92d3375-d907-414e-b45f-3169361e2e36           4          778
# bf08b5ad-ab60-4063-9e33-da305294a802           5          889
# f1d7450e-d921-4d17-857c-2b2cbc98f569           6          894
#
#                                       character_count  ordinal header_0  \
# file_id
# 6d783b84-c913-467e-b051-4454582f70e0             3103        0     part
# 2943c186-fb4c-4fa2-a4e4-a08701b33fc4             3173        1     part
# 783cbd98-a3dd-488c-8efc-a6806f49aef8             2872        2     part
# 6c9f8347-d76a-491e-8e5a-96c279089363             2878        3     part
# b92d3375-d907-414e-b45f-3169361e2e36             3526        4     part
# bf08b5ad-ab60-4063-9e33-da305294a802             4155        5     part
# f1d7450e-d921-4d17-857c-2b2cbc98f569             4026        6     part
#
#                                      headers       book  max_id
# file_id
# 6d783b84-c913-467e-b051-4454582f70e0    part  translate     668
# 2943c186-fb4c-4fa2-a4e4-a08701b33fc4    part  translate   11334
# 783cbd98-a3dd-488c-8efc-a6806f49aef8    part  translate   21955
# 6c9f8347-d76a-491e-8e5a-96c279089363    part  translate   32568
# b92d3375-d907-414e-b45f-3169361e2e36    part  translate   43347
# bf08b5ad-ab60-4063-9e33-da305294a802    part  translate   54237
# f1d7450e-d921-4d17-857c-2b2cbc98f569    part  translate   65132
