# %% [markdown]
# ### Build fragments

# %%
import pandas as pd

from tg.grammar_ru import CorpusReader
from tg.projects.book_tasks.fragments_builder import FragmentsBuilder
from pathlib import Path

# %% [markdown]
# Creating "Crime and Puhishment"(CiP) corpus

# %%
from tg.grammar_ru.corpus.corpus_builder import CorpusBuilder


CorpusBuilder.convert_interformat_folder_to_corpus(
    Path('files/crime_and_puhishment_corpus.base.zip'),
    Path('./files/mds'),
    ['book']
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
cip_path = Path('./files/crime_and_puhishment_corpus.base.zip')
cip_reader = CorpusReader(cip_path)
cip_reader.read_frames().first()
# Out:
#        word_id  sentence_id  word_index  paragraph_id  word_tail       word  \
# 0            0            0           0             0          1         At
# 1            1            0           1             0          1        the
# 2            2            0           2             0          1  beginning
# 3            3            0           3             0          1         of
# 4            4            0           4             0          0       July
# ...        ...          ...         ...           ...        ...        ...
# 43468    43468         1998          31           491          1         he
# 43469    43469         1998          32           491          1      tried
# 43470    43470         1998          33           491          1          .
# 43471    43471         1998          34           491          1          .
# 43472    43472         1998          35           491          0          .
#
#       word_type  word_length                               file_id  \
# 0           unk            2  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
# 1           unk            3  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
# 2           unk            9  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
# 3           unk            2  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
# 4           unk            4  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
# ...         ...          ...                                   ...
# 43468       unk            2  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
# 43469       unk            5  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
# 43470     punct            1  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
# 43471     punct            1  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
# 43472     punct            1  c0b7cc9b-fd17-4191-b08e-724f6bd4cefc
#
#                                   corpus_id
# 0      crime_and_puhishment_corpus.base.zip
# 1      crime_and_puhishment_corpus.base.zip
# 2      crime_and_puhishment_corpus.base.zip
# 3      crime_and_puhishment_corpus.base.zip
# 4      crime_and_puhishment_corpus.base.zip
# ...                                     ...
# 43468  crime_and_puhishment_corpus.base.zip
# 43469  crime_and_puhishment_corpus.base.zip
# 43470  crime_and_puhishment_corpus.base.zip
# 43471  crime_and_puhishment_corpus.base.zip
# 43472  crime_and_puhishment_corpus.base.zip
#
# [43473 rows x 10 columns]

# %% [markdown]
# Creating fragments (json/corpus)

# %%
fragments_builder = FragmentsBuilder(cip_reader, file_name="cip_fragments")
fragments_builder.construct_fragments_json()
fragments_builder.construct_fragments_corpus()
# Out:
# Processing frame with id: c0b7cc9b-fd17-4191-b08e-724f6bd4cefc, 2/6

# %%
cip_fragments_corpus = Path('./files/cip_fragments.base.zip')
cip_fragments_reader = CorpusReader(cip_fragments_corpus)

cip_fragments_reader.get_frames().first()
# Out:
#                                      id                               file_id  \
# 0  383540bd-8926-11ee-bd8a-e60418d033fb  2dc5d1e3-6158-4fd2-9842-cc6932378c5c
#
#    word  word_length                                             prompt  \
# 0     0            0  retell this text in simple sentences and simpl...
#
#                                       text_narrative  \
# 0  Yet everything worked out well. The caretaker'...
#
#                                          text_dialog retell  word_start_id  \
# 0  If the caretaker had asked him, “What do you w...                 43251
#
#    word_end_id  word_id  sentence_id  paragraph_id               corpus_id
# 0          187        1            1             1  cip_fragments.base.zip
